# %% [markdown]
# # Limpieza de datos de hospitalizaciones 2019

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df19 = pd.read_csv("1-2019.csv", delimiter= ";", encoding = "latin1")

df19.columns = df19.columns.str.strip()

# %%
# Mostrar los nombres de columnas para verificar
print("Columnas de df19:", df19.columns)
# Out:
# Columnas de df19: Index(['Diagnóstico principal (CIE10MC)', 'Total Nacional',
#        'Comunidades y Ciudades Autónomas', 'Provincias', 'Sexo', 'Total'],
#       dtype='object')

# %%
df19.head(10)
# Out:
#                      Diagnóstico principal (CIE10MC)  Total Nacional  \
# 0  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 1  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 2  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 3  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 4  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 5  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 6  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 7  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 8  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
# 9  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
#
#   Comunidades y Ciudades Autónomas  Provincias         Sexo    Total
# 0                     01 Andalucía  04 Almería  Ambos sexos    4.485
# 1                     01 Andalucía  04 Almería      Hombres    3.614
# 2                     01 Andalucía  04 Almería      Mujeres  872.000
# 3                     01 Andalucía    11 Cádiz  Ambos sexos    8.142
# 4                     01 Andalucía    11 Cádiz      Hombres    6.472
# 5                     01 Andalucía    11 Cádiz      Mujeres    1.670
# 6                     01 Andalucía  14 Córdoba  Ambos sexos    3.303
# 7                     01 Andalucía  14 Córdoba      Hombres    2.617
# 8                     01 Andalucía  14 Córdoba      Mujeres  686.000
# 9                     01 Andalucía  18 Granada  Ambos sexos    5.372

# %%
df19.dtypes
# Out:
# Diagnóstico principal (CIE10MC)      object
# Total Nacional                       object
# Comunidades y Ciudades Autónomas     object
# Provincias                           object
# Sexo                                 object
# Total                               float64
# dtype: object

# %%
# LIMPIEZA COLUMNA TOTAL
df19['Total'] = df19['Total'].astype(str).str.replace('.', '', regex=False).astype(int)

# %%
df19.dtypes
# Out:
# Diagnóstico principal (CIE10MC)     object
# Total Nacional                      object
# Comunidades y Ciudades Autónomas    object
# Provincias                          object
# Sexo                                object
# Total                                int64
# dtype: object

# %%
df19['Total'].isnull().sum()
# Out:
# 0

# %%
# CREACIÓN DE COLUMNA PROVINCIAS
df19['Comunidades y Ciudades Autónomas'] = df19['Comunidades y Ciudades Autónomas'].fillna('')
df19['Provincias'] = df19['Provincias'].fillna('')

# %%
df19['Combinada'] = df19['Comunidades y Ciudades Autónomas'].str.cat(df19['Provincias'], sep=' ')

# %%
df19.head(1)
# Out:
#                      Diagnóstico principal (CIE10MC)  Total Nacional  \
# 0  0202 Neoplasias malignas de tráquea, bronquios...  Total Nacional
#
#   Comunidades y Ciudades Autónomas  Provincias         Sexo  Total  \
# 0                     01 Andalucía  04 Almería  Ambos sexos   4485
#
#                  Combinada
# 0  01 Andalucía 04 Almería

# %%
df19 = df19[df19.columns[[0,4,5,6]]]

# %%
df19
# Out:
#                         Diagnóstico principal (CIE10MC)         Sexo  Total  \
# 0     0202 Neoplasias malignas de tráquea, bronquios...  Ambos sexos   4485
# 1     0202 Neoplasias malignas de tráquea, bronquios...      Hombres   3614
# 2     0202 Neoplasias malignas de tráquea, bronquios...      Mujeres   8720
# 3     0202 Neoplasias malignas de tráquea, bronquios...  Ambos sexos   8142
# 4     0202 Neoplasias malignas de tráquea, bronquios...      Hombres   6472
# ...                                                 ...          ...    ...
# 1555  1008 Otras enfermedades del aparato respirator...      Hombres   9410
# 1556  1008 Otras enfermedades del aparato respirator...      Mujeres   6520
# 1557  1008 Otras enfermedades del aparato respirator...  Ambos sexos   3024
# 1558  1008 Otras enfermedades del aparato respirator...      Hombres    151
# 1559  1008 Otras enfermedades del aparato respirator...      Mujeres   1514
#
#                     Combinada
# 0     01 Andalucía 04 Almería
# 1     01 Andalucía 04 Almería
# 2     01 Andalucía 04 Almería
# 3       01 Andalucía 11 Cádiz
# 4       01 Andalucía 11 Cádiz
# ...                       ...
# 1555                18 Ceuta
# 1556                18 Ceuta
# 1557              19 Melilla
# 1558              19 Melilla
# 1559              19 Melilla
#
# [1560 rows x 4 columns]

# %%
df19['Combinada'].unique()
# Out:
# array(['01 Andalucía 04 Almería', '01 Andalucía 11 Cádiz',
#        '01 Andalucía 14 Córdoba', '01 Andalucía 18 Granada',
#        '01 Andalucía 21 Huelva', '01 Andalucía 23 Jaén',
#        '01 Andalucía 29 Málaga', '01 Andalucía 41 Sevilla',
#        '02 Aragón 22 Huesca', '02 Aragón 44 Teruel',
#        '02 Aragón 50 Zaragoza', '03 Asturias, Principado de ',
#        '04 Balears, Illes ', '05 Canarias 35 Palmas, Las',
#        '05 Canarias 38 Santa Cruz de Tenerife', '06 Cantabria ',
#        '07 Castilla y León 05 Ávila', '07 Castilla y León 09 Burgos',
#        '07 Castilla y León 24 León', '07 Castilla y León 34 Palencia',
#        '07 Castilla y León 37 Salamanca', '07 Castilla y León 40 Segovia',
#        '07 Castilla y León 42 Soria', '07 Castilla y León 47 Valladolid',
#        '07 Castilla y León 49 Zamora',
#        '08 Castilla - La Mancha 02 Albacete',
#        '08 Castilla - La Mancha 13 Ciudad Real',
#        '08 Castilla - La Mancha 16 Cuenca',
#        '08 Castilla - La Mancha 19 Guadalajara',
#        '08 Castilla - La Mancha 45 Toledo', '09 Cataluña 08 Barcelona',
#        '09 Cataluña 17 Girona', '09 Cataluña 25 Lleida',
#        '09 Cataluña 43 Tarragona',
#        '10 Comunitat Valenciana 03 Alicante/Alacant',
#        '10 Comunitat Valenciana 12 Castellón/Castelló',
#        '10 Comunitat Valenciana 46 Valencia/València',
#        '11 Extremadura 06 Badajoz', '11 Extremadura 10 Cáceres',
#        '12 Galicia 15 Coruña, A', '12 Galicia 27 Lugo',
#        '12 Galicia 32 Ourense', '12 Galicia 36 Pontevedra',
#        '13 Madrid, Comunidad de ', '14 Murcia, Región de ',
#        '15 Navarra, Comunidad Foral de ', '16 País Vasco 01 Araba/Álava',
#        '16 País Vasco 48 Bizkaia', '16 País Vasco 20 Gipuzkoa',
#        '17 Rioja, La ', '18 Ceuta ', '19 Melilla '], dtype=object)

# %%
# RENOMBRADO DE COLUMNAS
df19.rename(
    columns = {'Combinada': 'Provincia',
              'Diagnóstico principal (CIE10MC)': 'Diagnóstico',
              'Total': 'Hospitalizaciones'},
    inplace = True
)

# %%
df19 = df19[['Diagnóstico', 'Provincia', 'Sexo', 'Hospitalizaciones']]

# %%
mapeo_combinada = {
    '01 Andalucía 04 Almería': 'Almería',
    '01 Andalucía 11 Cádiz': 'Cádiz',
    '01 Andalucía 14 Córdoba': 'Córdoba',
    '01 Andalucía 18 Granada': "Granada",
    '01 Andalucía 21 Huelva': 'Huelva',
    '01 Andalucía 23 Jaén': 'Jaén',
    '01 Andalucía 29 Málaga': 'Málaga',
    '01 Andalucía 41 Sevilla': 'Sevilla',
    '02 Aragón 22 Huesca': 'Huesca',
    '02 Aragón 44 Teruel': 'Teruel',
    '02 Aragón 50 Zaragoza': 'Zaragoza',
    '03 Asturias, Principado de ': 'Asturias',
    '04 Balears, Illes ': 'Islas Baleares',
    '05 Canarias 35 Las Palmas': 'Las Palmas',
    '05 Canarias 38 Santa Cruz de Tenerife': 'Santa Cruz de Tenerife',
    '06 Cantabria ': 'Cantabria',
    '07 Castilla y León 05 Ávila': 'Ávila',
    '07 Castilla y León 09 Burgos': 'Burgos',
    '07 Castilla y León 24 León': 'León',
    '07 Castilla y León 34 Palencia': 'Palencia',
    '07 Castilla y León 37 Salamanca': 'Salamanca',
    '07 Castilla y León 40 Segovia': 'Segovia',
    '07 Castilla y León 42 Soria': 'Soria',
    '07 Castilla y León 47 Valladolid': 'Valladolid',
    '07 Castilla y León 49 Zamora': 'Zamora',
    '08 Castilla - La Mancha 02 Albacete': 'Albacete',
    '08 Castilla - La Mancha 13 Ciudad Real': 'Ciudad Real',
    '08 Castilla - La Mancha 16 Cuenca': 'Cuenca',
    '08 Castilla - La Mancha 19 Guadalajara': 'Guadalajara',
    '08 Castilla - La Mancha 45 Toledo': 'Toledo',
    '09 Cataluña 08 Barcelona': 'Barcelona',
    '09 Cataluña 17 Girona': 'Girona',
    '09 Cataluña 25 Lleida': 'Lleida',
    '09 Cataluña 43 Tarragona': 'Tarragona',
    '10 Comunitat Valenciana 03 Alicante/Alacant': 'Alicante',
    '10 Comunitat Valenciana 12 Castellón/Castelló': 'Castellón',
    '10 Comunitat Valenciana 46 Valencia/València': 'Valencia',
    '11 Extremadura 06 Badajoz': 'Badajoz',
    '11 Extremadura 10 Cáceres': 'Cáceres',
    '12 Galicia 15 Coruña, A': 'A Coruña',
    '12 Galicia 27 Lugo': 'Lugo',
    '12 Galicia 32 Ourense': 'Ourense',
    '12 Galicia 36 Pontevedra': 'Pontevedra',
    '13 Madrid, Comunidad de ': 'Madrid',
    '14 Murcia, Región de ': 'Murcia',
    '15 Navarra, Comunidad Foral de ': 'Navarra',
    '16 País Vasco 01 Araba/Álava': 'Álava',
    '16 País Vasco 48 Bizkaia': 'Bizkaia',
    '16 País Vasco 20 Gipuzkoa': 'Gipuzkoa',
    '17 Rioja, La ': 'La Rioja',
    '18 Ceuta ': 'Ceuta',
    '19 Melilla ': 'Melilla'
}

df19['Provincia'] = df19['Provincia'].map(mapeo_combinada)

# %%
# Crear un filtro para seleccionar filas donde "Provincia" es NaN
filtro = df19['Provincia'].isna()

# Aplicar el filtro para obtener solo las filas donde "Provincia" es NaN
df19_nan_provincia = df19.loc[filtro]

# Mostrar el resultado
df19_nan_provincia
# Out:
#                                             Diagnóstico Provincia  \
# 39    0202 Neoplasias malignas de tráquea, bronquios...       NaN
# 40    0202 Neoplasias malignas de tráquea, bronquios...       NaN
# 41    0202 Neoplasias malignas de tráquea, bronquios...       NaN
# 195   0905 Enfermedad pulmonar cardíaca y enfermedad...       NaN
# 196   0905 Enfermedad pulmonar cardíaca y enfermedad...       NaN
# 197   0905 Enfermedad pulmonar cardíaca y enfermedad...       NaN
# 351   1001 Infecciones agudas de las vías respirator...       NaN
# 352   1001 Infecciones agudas de las vías respirator...       NaN
# 353   1001 Infecciones agudas de las vías respirator...       NaN
# 507                               1002 Neumonía J12-J18       NaN
# 508                               1002 Neumonía J12-J18       NaN
# 509                               1002 Neumonía J12-J18       NaN
# 663   1003 Otras infecciones agudas de las vias resp...       NaN
# 664   1003 Otras infecciones agudas de las vias resp...       NaN
# 665   1003 Otras infecciones agudas de las vias resp...       NaN
# 819   1004 Enfermedad crónica de amígdalas y adenoid...       NaN
# 820   1004 Enfermedad crónica de amígdalas y adenoid...       NaN
# 821   1004 Enfermedad crónica de amígdalas y adenoid...       NaN
# 975   1005 Otras enfermedades del tracto respiratori...       NaN
# 976   1005 Otras enfermedades del tracto respiratori...       NaN
# 977   1005 Otras enfermedades del tracto respiratori...       NaN
# 1131  1006 Enfermedad pulmonar obstructiva crónica y...       NaN
# 1132  1006 Enfermedad pulmonar obstructiva crónica y...       NaN
# 1133  1006 Enfermedad pulmonar obstructiva crónica y...       NaN
# 1287                                      1007 Asma J45       NaN
# 1288                                      1007 Asma J45       NaN
# 1289                                      1007 Asma J45       NaN
# 1443  1008 Otras enfermedades del aparato respirator...       NaN
# 1444  1008 Otras enfermedades del aparato respirator...       NaN
# 1445  1008 Otras enfermedades del aparato respirator...       NaN
#
#              Sexo  Hospitalizaciones
# 39    Ambos sexos               8683
# 40        Hombres               6501
# 41        Mujeres               2182
# 195   Ambos sexos                439
# 196       Hombres               1651
# 197       Mujeres               2739
# 351   Ambos sexos               6597
# 352       Hombres                283
# 353       Mujeres               3767
# 507   Ambos sexos               2613
# 508       Hombres              14029
# 509       Mujeres                121
# 663   Ambos sexos              10677
# 664       Hombres               4132
# 665       Mujeres               6545
# 819   Ambos sexos               6030
# 820       Hombres               3380
# 821       Mujeres               2640
# 975   Ambos sexos               2303
# 976       Hombres               1105
# 977       Mujeres               1198
# 1131  Ambos sexos              15893
# 1132      Hombres               9946
# 1133      Mujeres               5947
# 1287  Ambos sexos                213
# 1288      Hombres               5800
# 1289      Mujeres                155
# 1443  Ambos sexos              44504
# 1444      Hombres              19565
# 1445      Mujeres              24939

# %%
df19 = df19.dropna()

# %%
df19.head(3)
# Out:
#                                          Diagnóstico Provincia         Sexo  \
# 0  0202 Neoplasias malignas de tráquea, bronquios...   Almería  Ambos sexos
# 1  0202 Neoplasias malignas de tráquea, bronquios...   Almería      Hombres
# 2  0202 Neoplasias malignas de tráquea, bronquios...   Almería      Mujeres
#
#    Hospitalizaciones
# 0               4485
# 1               3614
# 2               8720

# %%
# CREACIÓN DE OTRA COLUMNA PROVINCIA ID
columna_duplicada = df19['Provincia']
if 'ColumnaDuplicada' in df19.columns:
    df19.drop(columns=['ColumnaDuplicada'], inplace=True)
df19.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df19.rename(
    columns = {'ColumnaDuplicada': 'Provincia_ID'},
    inplace = True
)

# %%
mapeo_provincias = {
    "Álava": 1,
    "Albacete": 2,
    "Alicante": 3,
    "Almería": 4,
    "Ávila": 5,
    "Badajoz": 6,
    "Islas Baleares": 7,
    "Barcelona": 8,
    "Burgos": 9,
    "Cáceres": 10,
    "Cádiz": 11,
    "Castellón": 12,
    "Ciudad Real": 13,
    "Córdoba": 14,
    "A Coruña": 15,
    "Cuenca": 16,
    "Girona": 17,
    "Granada": 18,
    "Guadalajara": 19,
    "Gipuzkoa": 20,
    "Huelva": 21,
    "Huesca": 22,
    "Jaén": 23,
    "León": 24,
    "Lleida": 25,
    "La Rioja": 26,
    "Lugo": 27,
    "Madrid": 28,
    "Málaga": 29,
    "Murcia": 30,
    "Navarra": 31,
    "Ourense": 32,
    "Asturias": 33,
    "Palencia": 34,
    "Las Palmas": 35,
    "Pontevedra": 36,
    "Salamanca": 37,
    "Santa Cruz de Tenerife": 38,
    "Cantabria": 39,
    "Segovia": 40,
    "Sevilla": 41,
    "Soria": 42,
    "Tarragona": 43,
    "Teruel": 44,
    "Toledo": 45,
    "Valencia": 46,
    "Valladolid": 47,
    "Bizkaia": 48,
    "Zamora": 49,
    "Zaragoza": 50,
    "Ceuta": 51,
    "Melilla": 52
}

df19['Provincia_ID'] = df19['Provincia_ID'].map(mapeo_provincias)

# %%
df19.head()
# Out:
#                                          Diagnóstico Provincia  Provincia_ID  \
# 0  0202 Neoplasias malignas de tráquea, bronquios...   Almería             4
# 1  0202 Neoplasias malignas de tráquea, bronquios...   Almería             4
# 2  0202 Neoplasias malignas de tráquea, bronquios...   Almería             4
# 3  0202 Neoplasias malignas de tráquea, bronquios...     Cádiz            11
# 4  0202 Neoplasias malignas de tráquea, bronquios...     Cádiz            11
#
#           Sexo  Hospitalizaciones
# 0  Ambos sexos               4485
# 1      Hombres               3614
# 2      Mujeres               8720
# 3  Ambos sexos               8142
# 4      Hombres               6472

# %%
df19['Provincia_ID'].isna().sum()
# Out:
# 0

# %%
df19['Diagnóstico'].unique()
# Out:
# array(['0202 Neoplasias malignas de tráquea, bronquios y pulmón C33-C34',
#        '0905 Enfermedad pulmonar cardíaca y enfermedades de la circulación pulmonar I26-I28',
#        '1001 Infecciones agudas de las vías respiratorias superiores y gripe J00-J11',
#        '1002 Neumonía J12-J18',
#        '1003 Otras infecciones agudas de las vias respiratorias inferiores J20-J22',
#        '1004 Enfermedad crónica de amígdalas y adenoides J35',
#        '1005 Otras enfermedades del tracto respiratorio superior J30-J34, J36-J39',
#        '1006 Enfermedad pulmonar obstructiva crónica y bronquiectasias J40-J44, J47',
#        '1007 Asma J45',
#        '1008 Otras enfermedades del aparato respiratorio J60-J99'],
#       dtype=object)

# %%
# SIMPLIFICACIÓN DE NOMBRES EN COLUMNA DIAGNÓSTICO
mapeo_diagnostico = {
    '0202 Neoplasias malignas de tráquea, bronquios y pulmón C33-C34': "Neoplasia maligna de tráquea, bronquios y pulmón",
    '0905 Enfermedad pulmonar cardíaca y enfermedades de la circulación pulmonar I26-I28': "Enfermedades de la circulación pulmonar",
    '1001 Infecciones agudas de las vías respiratorias superiores y gripe J00-J11': 'Infecciones/enfermedades de las vías respiratorias superiores y gripe',
    '1002 Neumonía J12-J18': 'Neumonía',
    '1003 Otras infecciones agudas de las vias respiratorias inferiores J20-J22':'Otras infecciones de las vías respiratorias inferiores',
    '1004 Enfermedad crónica de amígdalas y adenoides J35': 'Enfermedad crónica de amígdalas',
    '1005 Otras enfermedades del tracto respiratorio superior J30-J34, J36-J39': 'Infecciones/enfermedades de las vías respiratorias superiores y gripe',
    '1006 Enfermedad pulmonar obstructiva crónica y bronquiectasias J40-J44, J47': 'EPOC y bronquitis',
    '1007 Asma J45': 'Asma',
    '1008 Otras enfermedades del aparato respiratorio J60-J99': 'Neumoconiosis, enfermedades pulmonares por agentes externos y otras'
}

df19['Diagnóstico'] = df19['Diagnóstico'].map(mapeo_diagnostico)

# %%
df19.insert(0, 'Año', 2019)

# %%
df19 = df19[df19['Sexo'] != 'Ambos sexos']

# %%
df19
# Out:
#        Año                                        Diagnóstico Provincia  \
# 1     2019   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 2     2019   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 4     2019   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# 5     2019   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# 7     2019   Neoplasia maligna de tráquea, bronquios y pulmón   Córdoba
# ...    ...                                                ...       ...
# 1553  2019  Neumoconiosis, enfermedades pulmonares por age...  La Rioja
# 1555  2019  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1556  2019  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1558  2019  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1559  2019  Neumoconiosis, enfermedades pulmonares por age...   Melilla
#
#       Provincia_ID     Sexo  Hospitalizaciones
# 1                4  Hombres               3614
# 2                4  Mujeres               8720
# 4               11  Hombres               6472
# 5               11  Mujeres                167
# 7               14  Hombres               2617
# ...            ...      ...                ...
# 1553            26  Mujeres               4478
# 1555            51  Hombres               9410
# 1556            51  Mujeres               6520
# 1558            52  Hombres                151
# 1559            52  Mujeres               1514
#
# [1020 rows x 6 columns]

# %%
df19 = df19.reset_index()

# %%
df19.drop('index', axis=1, inplace=True)

# %%
df19
# Out:
#        Año                                        Diagnóstico Provincia  \
# 0     2019   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 1     2019   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 2     2019   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# 3     2019   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# 4     2019   Neoplasia maligna de tráquea, bronquios y pulmón   Córdoba
# ...    ...                                                ...       ...
# 1015  2019  Neumoconiosis, enfermedades pulmonares por age...  La Rioja
# 1016  2019  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1017  2019  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1018  2019  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1019  2019  Neumoconiosis, enfermedades pulmonares por age...   Melilla
#
#       Provincia_ID     Sexo  Hospitalizaciones
# 0                4  Hombres               3614
# 1                4  Mujeres               8720
# 2               11  Hombres               6472
# 3               11  Mujeres                167
# 4               14  Hombres               2617
# ...            ...      ...                ...
# 1015            26  Mujeres               4478
# 1016            51  Hombres               9410
# 1017            51  Mujeres               6520
# 1018            52  Hombres                151
# 1019            52  Mujeres               1514
#
# [1020 rows x 6 columns]

# %%
df19["Diagnóstico"].unique()
# Out:
# array(['Neoplasia maligna de tráquea, bronquios y pulmón',
#        'Enfermedades de la circulación pulmonar',
#        'Infecciones/enfermedades de las vías respiratorias superiores y gripe',
#        'Neumonía',
#        'Otras infecciones de las vías respiratorias inferiores',
#        'Enfermedad crónica de amígdalas', 'EPOC y bronquitis', 'Asma',
#        'Neumoconiosis, enfermedades pulmonares por agentes externos y otras'],
#       dtype=object)

# %%
# CREACIÓN COLUMNA DIAGNÓSTICO ID
columna_duplicada = df19['Diagnóstico']
if 'ColumnaDuplicada' in df19.columns:
    df19.drop(columns=['ColumnaDuplicada'], inplace=True)
df19.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df19.rename(
    columns = {'ColumnaDuplicada': 'Diagnóstico_ID'},
    inplace = True
)

# %%
mapeo_diagnostico = {
    'Neoplasia maligna de tráquea, bronquios y pulmón': 1,
    'Enfermedades de la circulación pulmonar':2,
    'Enfermedad crónica de amígdalas': 3,
    'Neumonía': 4,
    'Asma': 5,
    'EPOC y bronquitis': 6,
    'Infecciones/enfermedades de las vías respiratorias superiores y gripe': 7,
    'Otras infecciones de las vías respiratorias inferiores': 8,
    'Neumoconiosis, enfermedades pulmonares por agentes externos y otras': 9
}

df19['Diagnóstico_ID'] = df19['Diagnóstico_ID'].map(mapeo_diagnostico)

# %%
df19['Diagnóstico_ID'].unique()
# Out:
# array([1, 2, 7, 4, 8, 3, 6, 5, 9])

# %%
df19 = df19.groupby(['Diagnóstico_ID','Año','Diagnóstico','Sexo','Provincia','Provincia_ID'])['Hospitalizaciones'].sum().reset_index()

# %%
df19.to_csv("df19.csv", index=False, encoding="iso-8859-1")
