# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as snf
import seaborn as sns

# %%
df12 = pd.read_csv("df12.csv", encoding="iso-8859-1")
df13 = pd.read_csv("df13.csv", encoding="iso-8859-1")
df14 = pd.read_csv("df14.csv", encoding="iso-8859-1")
df15 = pd.read_csv("df15.csv", encoding="iso-8859-1")
df16 = pd.read_csv("df16.csv", encoding="iso-8859-1")
df17 = pd.read_csv("df17.csv", encoding="iso-8859-1")
df18 = pd.read_csv("df18.csv", encoding="iso-8859-1")
df19 = pd.read_csv("df19.csv", encoding="iso-8859-1")
df20 = pd.read_csv("df20.csv", encoding="iso-8859-1")
df21 = pd.read_csv("df21.csv", encoding="iso-8859-1")

# %%
df20
# Out:
#       Diagnóstico_ID   Año                                       Diagnóstico  \
# 0                  1  2020  Neoplasia maligna de tráquea, bronquios y pulmón
# 1                  1  2020  Neoplasia maligna de tráquea, bronquios y pulmón
# 2                  1  2020  Neoplasia maligna de tráquea, bronquios y pulmón
# 3                  1  2020  Neoplasia maligna de tráquea, bronquios y pulmón
# 4                  1  2020  Neoplasia maligna de tráquea, bronquios y pulmón
# ...              ...   ...                                               ...
# 1035              10  2020                                          COVID-19
# 1036              10  2020                                          COVID-19
# 1037              10  2020                                          COVID-19
# 1038              10  2020                                          COVID-19
# 1039              10  2020                                          COVID-19
#
# ...

# %%
df12
# Out:
#      Diagnóstico_ID   Año                                        Diagnóstico  \
# 0                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 1                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 2                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 3                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 4                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# ..              ...   ...                                                ...
# 931               9  2012  Neumoconiosis, enfermedades pulmonares por age...
# 932               9  2012  Neumoconiosis, enfermedades pulmonares por age...
# 933               9  2012  Neumoconiosis, enfermedades pulmonares por age...
# 934               9  2012  Neumoconiosis, enfermedades pulmonares por age...
# 935               9  2012  Neumoconiosis, enfermedades pulmonares por age...
#
# ...

# %%
df13
# Out:
#      Diagnóstico_ID   Año                                        Diagnóstico  \
# 0                 1  2013   Neoplasia maligna de tráquea, bronquios y pulmón
# 1                 1  2013   Neoplasia maligna de tráquea, bronquios y pulmón
# 2                 1  2013   Neoplasia maligna de tráquea, bronquios y pulmón
# 3                 1  2013   Neoplasia maligna de tráquea, bronquios y pulmón
# 4                 1  2013   Neoplasia maligna de tráquea, bronquios y pulmón
# ..              ...   ...                                                ...
# 931               9  2013  Neumoconiosis, enfermedades pulmonares por age...
# 932               9  2013  Neumoconiosis, enfermedades pulmonares por age...
# 933               9  2013  Neumoconiosis, enfermedades pulmonares por age...
# 934               9  2013  Neumoconiosis, enfermedades pulmonares por age...
# 935               9  2013  Neumoconiosis, enfermedades pulmonares por age...
#
# ...

# %%
df14
# 932               9  2017  Neumoconiosis, enfermedades pulmonares por age...
# 933               9  2017  Neumoconiosis, enfermedades pulmonares por age...
# 934               9  2017  Neumoconiosis, enfermedades pulmonares por age...
# 935               9  2017  Neumoconiosis, enfermedades pulmonares por age...
#
# ...

# %%
df18
# Out:
#      Diagnóstico_ID   Año                                        Diagnóstico  \
# 0                 1  2018   Neoplasia maligna de tráquea, bronquios y pulmón
# 1                 1  2018   Neoplasia maligna de tráquea, bronquios y pulmón
# 2                 1  2018   Neoplasia maligna de tráquea, bronquios y pulmón
# 3                 1  2018   Neoplasia maligna de tráquea, bronquios y pulmón
# 4                 1  2018   Neoplasia maligna de tráquea, bronquios y pulmón
# ..              ...   ...                                                ...
# 931               9  2018  Neumoconiosis, enfermedades pulmonares por age...
# 932               9  2018  Neumoconiosis, enfermedades pulmonares por age...
# 933               9  2018  Neumoconiosis, enfermedades pulmonares por age...
# 934               9  2018  Neumoconiosis, enfermedades pulmonares por age...
# 935               9  2018  Neumoconiosis, enfermedades pulmonares por age...
#
# ...

# %%
df19.isna().sum()
# Out:
# Diagnóstico_ID       0
# Año                  0
# Diagnóstico          0
# Sexo                 0
# Provincia            0
# Provincia_ID         0
# Hospitalizaciones    0
# dtype: int64

# %%
data_concatenada = pd.concat([df12,df13,df14,df15,df16,df17,df18,df19,df20,df21], ignore_index=True)

# %%
filtro = data_concatenada.groupby('Provincia')

# %%
print(list(filtro))
# Out:
# [('A Coruña',       Diagnóstico_ID   Año                                        Diagnóstico  \
# 0                  1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 52                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 104                2  2012            Enfermedades de la circulación pulmonar
# 156                2  2012            Enfermedades de la circulación pulmonar
# 208                3  2012                    Enfermedad crónica de amígdalas
# ...              ...   ...                                                ...
# 9272               8  2021  Otras infecciones de las vias respiratorias in...
# 9324               9  2021  Neumoconiosis, enfermedades pulmonares por age...
# 9376               9  2021  Neumoconiosis, enfermedades pulmonares por age...
# 9428              10  2021                                           COVID-19
# 9480              10  2021                                           COVID-19
#
# ...

# %%
filtro.get_group("Madrid")
# Out:
#       Diagnóstico_ID   Año                                        Diagnóstico  \
# 30                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 82                 1  2012   Neoplasia maligna de tráquea, bronquios y pulmón
# 134                2  2012            Enfermedades de la circulación pulmonar
# 186                2  2012            Enfermedades de la circulación pulmonar
# 238                3  2012                    Enfermedad crónica de amígdalas
# ...              ...   ...                                                ...
# 9302               8  2021  Otras infecciones de las vias respiratorias in...
# 9354               9  2021  Neumoconiosis, enfermedades pulmonares por age...
# 9406               9  2021  Neumoconiosis, enfermedades pulmonares por age...
# 9458              10  2021                                           COVID-19
# 9510              10  2021                                           COVID-19
#
# ...

# %%
data_concatenada.to_csv("Hospitalizaciones.csv", index=False, encoding="iso-8859-1")
