# %%
# Limpieza de datos de hospitalizaciones 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as snf
import seaborn as sns

# %%
df20 = pd.read_csv("1-2020.csv", delimiter= ";", encoding = "latin1")
df20.columns = df20.columns.str.strip()

# %%
# Mostrar los nombres de columnas para verificar
print("Columnas de df20:", df20.columns)
# Out:
# Columnas de df20: Index(['Diagnóstico principal (CIE10MC)', 'Total Nacional',
#        'Comunidades y Ciudades Autónomas', 'Provincias', 'Sexo', 'Total'],
#       dtype='object')

# %%
df20.head(50)
# Out:
#    Diagnóstico principal (CIE10MC)  Total Nacional  \
# 0              0106 COVID-19 U07.1  Total Nacional
# 1              0106 COVID-19 U07.1  Total Nacional
# 2              0106 COVID-19 U07.1  Total Nacional
# 3              0106 COVID-19 U07.1  Total Nacional
# 4              0106 COVID-19 U07.1  Total Nacional
# 5              0106 COVID-19 U07.1  Total Nacional
# 6              0106 COVID-19 U07.1  Total Nacional
# 7              0106 COVID-19 U07.1  Total Nacional
# 8              0106 COVID-19 U07.1  Total Nacional
# 9              0106 COVID-19 U07.1  Total Nacional
# 10             0106 COVID-19 U07.1  Total Nacional
# 11             0106 COVID-19 U07.1  Total Nacional
# 12             0106 COVID-19 U07.1  Total Nacional
# 13             0106 COVID-19 U07.1  Total Nacional
# 14             0106 COVID-19 U07.1  Total Nacional
# 15             0106 COVID-19 U07.1  Total Nacional
# 16             0106 COVID-19 U07.1  Total Nacional
# 17             0106 COVID-19 U07.1  Total Nacional
# 18             0106 COVID-19 U07.1  Total Nacional
# 19             0106 COVID-19 U07.1  Total Nacional
# 20             0106 COVID-19 U07.1  Total Nacional
# 21             0106 COVID-19 U07.1  Total Nacional
# 22             0106 COVID-19 U07.1  Total Nacional
# 23             0106 COVID-19 U07.1  Total Nacional
# 24             0106 COVID-19 U07.1  Total Nacional
# 25             0106 COVID-19 U07.1  Total Nacional
# 26             0106 COVID-19 U07.1  Total Nacional
# 27             0106 COVID-19 U07.1  Total Nacional
# 28             0106 COVID-19 U07.1  Total Nacional
# 29             0106 COVID-19 U07.1  Total Nacional
# 30             0106 COVID-19 U07.1  Total Nacional
# 31             0106 COVID-19 U07.1  Total Nacional
# 32             0106 COVID-19 U07.1  Total Nacional
# 33             0106 COVID-19 U07.1  Total Nacional
# 34             0106 COVID-19 U07.1  Total Nacional
# 35             0106 COVID-19 U07.1  Total Nacional
# 36             0106 COVID-19 U07.1  Total Nacional
# 37             0106 COVID-19 U07.1  Total Nacional
# 38             0106 COVID-19 U07.1  Total Nacional
# 39             0106 COVID-19 U07.1  Total Nacional
# 40             0106 COVID-19 U07.1  Total Nacional
# 41             0106 COVID-19 U07.1  Total Nacional
# 42             0106 COVID-19 U07.1  Total Nacional
# 43             0106 COVID-19 U07.1  Total Nacional
# 44             0106 COVID-19 U07.1  Total Nacional
# 45             0106 COVID-19 U07.1  Total Nacional
# 46             0106 COVID-19 U07.1  Total Nacional
# 47             0106 COVID-19 U07.1  Total Nacional
# 48             0106 COVID-19 U07.1  Total Nacional
# 49             0106 COVID-19 U07.1  Total Nacional
#
#    Comunidades y Ciudades Autónomas                 Provincias         Sexo  \
# 0                               NaN                        NaN  Ambos sexos
# 1                               NaN                        NaN      Hombres
# 2                               NaN                        NaN      Mujeres
# 3                      01 Andalucía                 04 Almería  Ambos sexos
# 4                      01 Andalucía                 04 Almería      Hombres
# 5                      01 Andalucía                 04 Almería      Mujeres
# 6                      01 Andalucía                   11 Cádiz  Ambos sexos
# 7                      01 Andalucía                   11 Cádiz      Hombres
# 8                      01 Andalucía                   11 Cádiz      Mujeres
# 9                      01 Andalucía                 14 Córdoba  Ambos sexos
# 10                     01 Andalucía                 14 Córdoba      Hombres
# 11                     01 Andalucía                 14 Córdoba      Mujeres
# 12                     01 Andalucía                 18 Granada  Ambos sexos
# 13                     01 Andalucía                 18 Granada      Hombres
# 14                     01 Andalucía                 18 Granada      Mujeres
# 15                     01 Andalucía                  21 Huelva  Ambos sexos
# 16                     01 Andalucía                  21 Huelva      Hombres
# 17                     01 Andalucía                  21 Huelva      Mujeres
# 18                     01 Andalucía                    23 Jaén  Ambos sexos
# 19                     01 Andalucía                    23 Jaén      Hombres
# 20                     01 Andalucía                    23 Jaén      Mujeres
# 21                     01 Andalucía                  29 Málaga  Ambos sexos
# 22                     01 Andalucía                  29 Málaga      Hombres
# 23                     01 Andalucía                  29 Málaga      Mujeres
# 24                     01 Andalucía                 41 Sevilla  Ambos sexos
# 25                     01 Andalucía                 41 Sevilla      Hombres
# 26                     01 Andalucía                 41 Sevilla      Mujeres
# 27                        02 Aragón                  22 Huesca  Ambos sexos
# 28                        02 Aragón                  22 Huesca      Hombres
# 29                        02 Aragón                  22 Huesca      Mujeres
# 30                        02 Aragón                  44 Teruel  Ambos sexos
# 31                        02 Aragón                  44 Teruel      Hombres
# 32                        02 Aragón                  44 Teruel      Mujeres
# 33                        02 Aragón                50 Zaragoza  Ambos sexos
# 34                        02 Aragón                50 Zaragoza      Hombres
# 35                        02 Aragón                50 Zaragoza      Mujeres
# 36       03 Asturias, Principado de                        NaN  Ambos sexos
# 37       03 Asturias, Principado de                        NaN      Hombres
# 38       03 Asturias, Principado de                        NaN      Mujeres
# 39                04 Balears, Illes                        NaN  Ambos sexos
# 40                04 Balears, Illes                        NaN      Hombres
# 41                04 Balears, Illes                        NaN      Mujeres
# 42                      05 Canarias             35 Palmas, Las  Ambos sexos
# 43                      05 Canarias             35 Palmas, Las      Hombres
# 44                      05 Canarias             35 Palmas, Las      Mujeres
# 45                      05 Canarias  38 Santa Cruz de Tenerife  Ambos sexos
# 46                      05 Canarias  38 Santa Cruz de Tenerife      Hombres
# 47                      05 Canarias  38 Santa Cruz de Tenerife      Mujeres
# 48                     06 Cantabria                        NaN  Ambos sexos
# 49                     06 Cantabria                        NaN      Hombres
#
#         Total
# 0   1.556.482
# 1     896.018
# 2     660.463
# 3      10.321
# 4       6.655
# 5       3.665
# 6      19.301
# 7      11.491
# 8       7.810
# 9      17.557
# 10     10.035
# 11      7.522
# 12     34.242
# 13     20.003
# 14     14.239
# 15      7.804
# 16      4.282
# 17      3.522
# 18     18.604
# 19     11.656
# 20      6.948
# 21     26.665
# 22     15.910
# 23     10.756
# 24     44.456
# 25     26.225
# 26     18.231
# 27     11.976
# 28      7.184
# 29      4.792
# 30      8.617
# 31      4.984
# 32      3.633
# 33     53.475
# 34     30.263
# 35     23.212
# 36     41.023
# 37     23.287
# 38     17.736
# 39     28.108
# 40     17.201
# 41     10.907
# 42     10.725
# 43      6.637
# 44      4.088
# 45     12.613
# 46      7.633
# 47      4.979
# 48     12.460
# 49      7.411

# %%
df20.dtypes
# Out:
# Diagnóstico principal (CIE10MC)     object
# Total Nacional                      object
# Comunidades y Ciudades Autónomas    object
# Provincias                          object
# Sexo                                object
# Total                               object
# dtype: object

# %%
# LIMPIEZA COLUMNA TOTAL
df20['Total'] = pd.to_numeric(df20['Total'].astype(str).str.replace('.', '', regex=False), errors='coerce').fillna(0).astype(int)

# %%
df20['Total'] = df20['Total'].apply(lambda x: str(x).replace('.', '') if pd.notnull(x) else '0').astype(int)

# %%
df20['Total'] = df20['Total'].replace('', '0').astype(str).str.replace('.', '', regex=False).astype(int)

# %%
df20.dtypes
# Out:
# Diagnóstico principal (CIE10MC)     object
# Total Nacional                      object
# Comunidades y Ciudades Autónomas    object
# Provincias                          object
# Sexo                                object
# Total                                int32
# dtype: object

# %%
df20 = df20.iloc[3:]

# %%
df20.head()
# Out:
#   Diagnóstico principal (CIE10MC)  Total Nacional  \
# 3             0106 COVID-19 U07.1  Total Nacional
# 4             0106 COVID-19 U07.1  Total Nacional
# 5             0106 COVID-19 U07.1  Total Nacional
# 6             0106 COVID-19 U07.1  Total Nacional
# 7             0106 COVID-19 U07.1  Total Nacional
#
#   Comunidades y Ciudades Autónomas  Provincias         Sexo  Total
# 3                     01 Andalucía  04 Almería  Ambos sexos  10321
# 4                     01 Andalucía  04 Almería      Hombres   6655
# 5                     01 Andalucía  04 Almería      Mujeres   3665
# 6                     01 Andalucía    11 Cádiz  Ambos sexos  19301
# 7                     01 Andalucía    11 Cádiz      Hombres  11491

# %%
df20 = df20.reset_index()

# %%
df20.drop('index', axis=1, inplace=True)

# %%
df20['Total'].isnull().sum()
# Out:
# 0

# %%
df20['Comunidades y Ciudades Autónomas'] = df20['Comunidades y Ciudades Autónomas'].fillna('')
df20['Provincias'] = df20['Provincias'].fillna('')

# %%
df20['Combinada'] = df20['Comunidades y Ciudades Autónomas'].str.cat(df20['Provincias'], sep=' ')

# %%
df20.head(1)
# Out:
#   Diagnóstico principal (CIE10MC)  Total Nacional  \
# 0             0106 COVID-19 U07.1  Total Nacional
#
#   Comunidades y Ciudades Autónomas  Provincias         Sexo  Total  \
# 0                     01 Andalucía  04 Almería  Ambos sexos  10321
#
#                  Combinada
# 0  01 Andalucía 04 Almería

# %%
df20 = df20[df20.columns[[0,4,5,6]]]

# %%
df20
# Out:
#                         Diagnóstico principal (CIE10MC)         Sexo  Total  \
# 0                                   0106 COVID-19 U07.1  Ambos sexos  10321
# 1                                   0106 COVID-19 U07.1      Hombres   6655
# 2                                   0106 COVID-19 U07.1      Mujeres   3665
# 3                                   0106 COVID-19 U07.1  Ambos sexos  19301
# 4                                   0106 COVID-19 U07.1      Hombres  11491
# ...                                                 ...          ...    ...
# 1741  1008 Otras enfermedades del sistema respirator...      Hombres    592
# 1742  1008 Otras enfermedades del sistema respirator...      Mujeres    583
# 1743  1008 Otras enfermedades del sistema respirator...  Ambos sexos   1730
# 1744  1008 Otras enfermedades del sistema respirator...      Hombres   1114
# 1745  1008 Otras enfermedades del sistema respirator...      Mujeres    615
#
#                     Combinada
# 0     01 Andalucía 04 Almería
# 1     01 Andalucía 04 Almería
# 2     01 Andalucía 04 Almería
# 3       01 Andalucía 11 Cádiz
# 4       01 Andalucía 11 Cádiz
# ...                       ...
# 1741                18 Ceuta
# 1742                18 Ceuta
# 1743              19 Melilla
# 1744              19 Melilla
# 1745              19 Melilla
#
# [1746 rows x 4 columns]

# %%
df20['Combinada'].unique()
# Out:
# array(['01 Andalucía 04 Almería', '01 Andalucía 11 Cádiz',
#        '01 Andalucía 14 Córdoba', '01 Andalucía 18 Granada',
#        '01 Andalucía 21 Huelva', '01 Andalucía 23 Jaén',
#        '01 Andalucía 29 Málaga', '01 Andalucía 41 Sevilla',
#        '02 Aragón 22 Huesca', '02 Aragón 44 Teruel',
#        '02 Aragón 50 Zaragoza', '03 Asturias, Principado de ',
#        '04 Balears, Illes ', '05 Canarias 35 Palmas, Las',
#        '05 Canarias 38 Santa Cruz de Tenerife', '06 Cantabria ',
#        '07 Castilla y León 05 Ávila', '07 Castilla y León 09 Burgos',
#        '07 Castilla y León 24 León', '07 Castilla y León 34 Palencia',
#        '07 Castilla y León 37 Salamanca', '07 Castilla y León 40 Segovia',
#        '07 Castilla y León 42 Soria', '07 Castilla y León 47 Valladolid',
#        '07 Castilla y León 49 Zamora',
#        '08 Castilla - La Mancha 02 Albacete',
#        '08 Castilla - La Mancha 13 Ciudad Real',
#        '08 Castilla - La Mancha 16 Cuenca',
#        '08 Castilla - La Mancha 19 Guadalajara',
#        '08 Castilla - La Mancha 45 Toledo', '09 Cataluña 08 Barcelona',
#        '09 Cataluña 17 Girona', '09 Cataluña 25 Lleida',
#        '09 Cataluña 43 Tarragona',
#        '10 Comunitat Valenciana 03 Alicante/Alacant',
#        '10 Comunitat Valenciana 12 Castellón/Castelló',
#        '10 Comunitat Valenciana 46 Valencia/València',
#        '11 Extremadura 06 Badajoz', '11 Extremadura 10 Cáceres',
#        '12 Galicia 15 Coruña, A', '12 Galicia 27 Lugo',
#        '12 Galicia 32 Ourense', '12 Galicia 36 Pontevedra',
#        '13 Madrid, Comunidad de ', '14 Murcia, Región de ',
#        '15 Navarra, Comunidad Foral de ', '16 País Vasco 01 Araba/Álava',
#        '16 País Vasco 48 Bizkaia', '16 País Vasco 20 Gipuzkoa',
#        '17 Rioja, La ', '18 Ceuta ', '19 Melilla ', ' '], dtype=object)

# %%
# RENOMBRADO DE COLUMNAS
df20.rename(
    columns = {'Combinada': 'Provincia',
              'Diagnóstico principal (CIE10MC)': 'Diagnóstico',
              'Total': 'Hospitalizaciones'},
    inplace = True
)

# %%
df20 = df20[['Diagnóstico', 'Provincia', 'Sexo', 'Hospitalizaciones']]

# %%
mapeo_combinada = {
    '01 Andalucía 04 Almería': 'Almería',
    '01 Andalucía 11 Cádiz': 'Cádiz',
    '01 Andalucía 14 Córdoba': 'Córdoba',
    '01 Andalucía 18 Granada': "Granada",
    '01 Andalucía 21 Huelva': 'Huelva',
    '01 Andalucía 23 Jaén': 'Jaén',
    '01 Andalucía 29 Málaga': 'Málaga',
    '01 Andalucía 41 Sevilla': 'Sevilla',
    '02 Aragón 22 Huesca': 'Huesca',
    '02 Aragón 44 Teruel': 'Teruel',
    '02 Aragón 50 Zaragoza': 'Zaragoza',
    '03 Asturias, Principado de ': 'Asturias',
    '04 Balears, Illes ': 'Islas Baleares',
    '05 Canarias 35 Palmas, Las': 'Islas Canarias',
    '05 Canarias 38 Santa Cruz de Tenerife': 'Islas Canarias',
    '06 Cantabria ': 'Cantabria',
    '07 Castilla y León 05 Ávila': 'Ávila',
    '07 Castilla y León 09 Burgos': 'Burgos',
    '07 Castilla y León 24 León': 'León',
    '07 Castilla y León 34 Palencia': 'Palencia',
    '07 Castilla y León 37 Salamanca': 'Salamanca',
    '07 Castilla y León 40 Segovia': 'Segovia',
    '07 Castilla y León 42 Soria': 'Soria',
    '07 Castilla y León 47 Valladolid': 'Valladolid',
    '07 Castilla y León 49 Zamora': 'Zamora',
    '08 Castilla - La Mancha 02 Albacete': 'Albacete',
    '08 Castilla - La Mancha 13 Ciudad Real': 'Ciudad Real',
    '08 Castilla - La Mancha 16 Cuenca': 'Cuenca',
    '08 Castilla - La Mancha 19 Guadalajara': 'Guadalajara',
    '08 Castilla - La Mancha 45 Toledo': 'Toledo',
    '09 Cataluña 08 Barcelona': 'Barcelona',
    '09 Cataluña 17 Girona': 'Girona',
    '09 Cataluña 25 Lleida': 'Lleida',
    '09 Cataluña 43 Tarragona': 'Tarragona',
    '10 Comunitat Valenciana 03 Alicante/Alacant': 'Alicante',
    '10 Comunitat Valenciana 12 Castellón/Castelló': 'Castellón',
    '10 Comunitat Valenciana 46 Valencia/València': 'Valencia',
    '11 Extremadura 06 Badajoz': 'Badajoz',
    '11 Extremadura 10 Cáceres': 'Cáceres',
    '12 Galicia 15 Coruña, A': 'A Coruña',
    '12 Galicia 27 Lugo': 'Lugo',
    '12 Galicia 32 Ourense': 'Ourense',
    '12 Galicia 36 Pontevedra': 'Pontevedra',
    '13 Madrid, Comunidad de ': 'Madrid',
    '14 Murcia, Región de ': 'Murcia',
    '15 Navarra, Comunidad Foral de ': 'Navarra',
    '16 País Vasco 01 Araba/Álava': 'Álava',
    '16 País Vasco 48 Bizkaia': 'Bizkaia',
    '16 País Vasco 20 Gipuzkoa': 'Gipuzkoa',
    '17 Rioja, La ': 'La Rioja',
    '18 Ceuta ': 'Ceuta',
    '19 Melilla ': 'Melilla'
}

df20['Provincia'] = df20['Provincia'].map(mapeo_combinada)

# %%
df20.head(3)
# Out:
#            Diagnóstico Provincia         Sexo  Hospitalizaciones
# 0  0106 COVID-19 U07.1   Almería  Ambos sexos              10321
# 1  0106 COVID-19 U07.1   Almería      Hombres               6655
# 2  0106 COVID-19 U07.1   Almería      Mujeres               3665

# %%
# CREACIÓN DE OTRA COLUMNA PROVINCIA ID
columna_duplicada = df20['Provincia']
if 'ColumnaDuplicada' in df20.columns:
    df20.drop(columns=['ColumnaDuplicada'], inplace=True)
df20.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df20.rename(
    columns = {'ColumnaDuplicada': 'Provincia_ID'},
    inplace = True
)

# %%
mapeo_provincias = {
    "Álava": 1,
    "Albacete": 2,
    "Alicante": 3,
    "Almería": 4,
    "Ávila": 5,
    "Badajoz": 6,
    "Islas Baleares": 7,
    "Barcelona": 8,
    "Burgos": 9,
    "Cáceres": 10,
    "Cádiz": 11,
    "Castellón": 12,
    "Ciudad Real": 13,
    "Córdoba": 14,
    "A Coruña": 15,
    "Cuenca": 16,
    "Girona": 17,
    "Granada": 18,
    "Guadalajara": 19,
    "Gipuzkoa": 20,
    "Huelva": 21,
    "Huesca": 22,
    "Jaén": 23,
    "León": 24,
    "Lleida": 25,
    "La Rioja": 26,
    "Lugo": 27,
    "Madrid": 28,
    "Málaga": 29,
    "Murcia": 30,
    "Navarra": 31,
    "Ourense": 32,
    "Asturias": 33,
    "Palencia": 34,
    "Islas Canarias": [35, 38],
    "Pontevedra": 36,
    "Salamanca": 37,
    "Cantabria": 39,
    "Segovia": 40,
    "Sevilla": 41,
    "Soria": 42,
    "Tarragona": 43,
    "Teruel": 44,
    "Toledo": 45,
    "Valencia": 46,
    "Valladolid": 47,
    "Bizkaia": 48,
    "Zamora": 49,
    "Zaragoza": 50,
    "Ceuta": 51,
    "Melilla": 52
}

df20['Provincia_ID'] = df20['Provincia_ID'].map(mapeo_provincias)

# %%
df20.head()
# Out:
#            Diagnóstico Provincia Provincia_ID         Sexo  Hospitalizaciones
# 0  0106 COVID-19 U07.1   Almería            4  Ambos sexos              10321
# 1  0106 COVID-19 U07.1   Almería            4      Hombres               6655
# 2  0106 COVID-19 U07.1   Almería            4      Mujeres               3665
# 3  0106 COVID-19 U07.1     Cádiz           11  Ambos sexos              19301
# 4  0106 COVID-19 U07.1     Cádiz           11      Hombres              11491

# %%
df20['Provincia_ID'].isna().sum()
# Out:
# 30

# %%
df20['Diagnóstico'].unique()
# Out:
# array(['0106 COVID-19 U07.1',
#        '0202 Neoplasias malignas de tráquea, bronquios y pulmón  C33-C34',
#        '0905 Enfermedades de la circulación pulmonar I26-I28',
#        '1001 Infecciones agudas de las vías respiratorias superiores y gripe J00-J11',
#        '1002 Neumonía J12-J18',
#        '1003 Bronquitis y bronquiolitis agudas J20-J22',
#        '1004 Enfermedad crónica de amígdalas y adenoides J35',
#        '1005 Otras enfermedades del tracto respiratorio superior J30-J34, J36-J39',
#        '1006 Enfermedad pulmonar obstructiva crónica y bronquiectasias J40-J44, J47',
#        '1007 Asma J45',
#        '1008 Otras enfermedades del sistema respiratorio J60-J99'],
#       dtype=object)

# %%
mapeo_diagnostico = {
    '0202 Neoplasias malignas de tráquea, bronquios y pulmón C33-C34': "Neoplasia maligna de tráquea, bronquios y pulmón",
    '0905 Enfermedad pulmonar cardíaca y enfermedades de la circulación pulmonar I26-I28': "Enfermedades de la circulación pulmonar",
    '1001 Infecciones agudas de las vías respiratorias superiores y gripe J00-J11': 'Infecciones de las vías respiratorias superiores y gripe',
    '1002 Neumonía J12-J18': 'Neumonía',
    '1003 Otras infecciones agudas de las vias respiratorias inferiores J20-J22':'Otras infecciones de las vias respiratorias inferiores',
    '1004 Enfermedad crónica de amígdalas y adenoides J35': 'Enfermedad crónica de amígdalas',
    '1005 Otras enfermedades del tracto respiratorio superior J30-J34, J36-J39': 'Otras infecciones del tracto respiratorio superior',
    '1006 Enfermedad pulmonar obstructiva crónica y bronquiectasias J40-J44, J47': 'EPOC y bronquitis',
    '1007 Asma J45': 'Asma',
    '1008 Otras enfermedades del aparato respiratorio J60-J99': 'Otras enfermedades del aparato respiratorio',
    '0106 COVID-19 U07.1': 'Covid'
}
df20['Diagnóstico'] = df20['Diagnóstico'].map(mapeo_diagnostico)

# %%
df20.insert(0, 'Año', 2020)

# %%
columna_duplicada = df20['Diagnóstico']
if 'ColumnaDuplicada' in df20.columns:
    df20.drop(columns=['ColumnaDuplicada'], inplace=True)
df20.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df20.rename(
    columns = 
    {'ColumnaDuplicada': 'Diagnóstico_ID'
},
inplace = True)

# %%
df20['Diagnóstico'].unique()
# Out:
# array(['Covid', nan,
#        'Infecciones de las vías respiratorias superiores y gripe',
#        'Neumonía', 'Enfermedad crónica de amígdalas',
#        'Otras infecciones del tracto respiratorio superior',
#        'EPOC y bronquitis', 'Asma'], dtype=object)

# %%
df20
# Out:
#        Año Diagnóstico Diagnóstico_ID Provincia Provincia_ID         Sexo  \
# 0     2020       Covid          Covid   Almería            4  Ambos sexos
# 1     2020       Covid          Covid   Almería            4      Hombres
# 2     2020       Covid          Covid   Almería            4      Mujeres
# 3     2020       Covid          Covid     Cádiz           11  Ambos sexos
# 4     2020       Covid          Covid     Cádiz           11      Hombres
# ...    ...         ...            ...       ...          ...          ...
# 1741  2020         NaN            NaN     Ceuta           51      Hombres
# 1742  2020         NaN            NaN     Ceuta           51      Mujeres
# 1743  2020         NaN            NaN   Melilla           52  Ambos sexos
# 1744  2020         NaN            NaN   Melilla           52      Hombres
# 1745  2020         NaN            NaN   Melilla           52      Mujeres
#
#       Hospitalizaciones
# 0                 10321
# 1                  6655
# 2                  3665
# 3                 19301
# 4                 11491
# ...                 ...
# 1741                592
# 1742                583
# 1743               1730
# 1744               1114
# 1745                615
#
# [1746 rows x 7 columns]

# %%
mapeo_diagnostico = {
        'Neoplasia maligna de tráquea, bronquios y pulmón':1,
        'Enfermedades de la circulación pulmonar':2,
        'Bronquitis y bronquiolitis aguda':3,
        'Enfermedad crónica de amígdalas':4,
        'Otras infecciones del tracto respiratorio superior':5,
        'Neumonía':6,
        'Gripe':7, 
        'EPOC y bronquitis':8, 
        'Asma':9,
        'Otras asociadas a EPOC':10,
        'Neumoconiosis y enfermedades pulmonares por agentes externos':11,
        'Covid': 12
}

df20['Diagnóstico_ID'] = df20['Diagnóstico_ID'].map(mapeo_diagnostico)

# %%
df20['Diagnóstico_ID'] = pd.to_numeric(df20['Diagnóstico_ID'], errors='coerce').astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df20['Diagnóstico_ID'] = pd.to_numeric(df20['Diagnóstico_ID'], errors='coerce').astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer
