# %% [markdown]
# # Limpieza de datos de hospitalizaciones 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as snf
import seaborn as sns

# %%
df20 = pd.read_csv("1-2020.csv", delimiter= ";", encoding = "latin1")
df20.columns = df20.columns.str.strip()

# %%
# Mostrar los nombres de columnas para verificar
print("Columnas de df20:", df20.columns)
# Out:
# Columnas de df20: Index(['Diagnóstico principal (CIE10MC)', 'Total Nacional',
#        'Comunidades y Ciudades Autónomas', 'Provincias', 'Sexo', 'Total'],
#       dtype='object')

# %%
df20.dtypes
# Out:
# Diagnóstico principal (CIE10MC)     object
# Total Nacional                      object
# Comunidades y Ciudades Autónomas    object
# Provincias                          object
# Sexo                                object
# Total                               object
# dtype: object

# %%
# LIMPIEZA COLUMNA TOTAL
df20['Total'] = pd.to_numeric(df20['Total'].astype(str).str.replace('.', '', regex=False), errors='coerce').fillna(0).astype(int)

# %%
df20['Total'] = df20['Total'].apply(lambda x: str(x).replace('.', '') if pd.notnull(x) else '0').astype(int)

# %%
df20['Total'] = df20['Total'].replace('', '0').astype(str).str.replace('.', '', regex=False).astype(int)

# %%
df20.dtypes
# Out:
# Diagnóstico principal (CIE10MC)     object
# Total Nacional                      object
# Comunidades y Ciudades Autónomas    object
# Provincias                          object
# Sexo                                object
# Total                                int32
# dtype: object

# %%
df20.head()
# Out:
#   Diagnóstico principal (CIE10MC)  Total Nacional  \
# 0             0106 COVID-19 U07.1  Total Nacional
# 1             0106 COVID-19 U07.1  Total Nacional
# 2             0106 COVID-19 U07.1  Total Nacional
# 3             0106 COVID-19 U07.1  Total Nacional
# 4             0106 COVID-19 U07.1  Total Nacional
#
#   Comunidades y Ciudades Autónomas  Provincias         Sexo    Total
# 0                              NaN         NaN  Ambos sexos  1556482
# 1                              NaN         NaN      Hombres   896018
# 2                              NaN         NaN      Mujeres   660463
# 3                     01 Andalucía  04 Almería  Ambos sexos    10321
# 4                     01 Andalucía  04 Almería      Hombres     6655

# %%
df20['Total'].isnull().sum()
# Out:
# 0

# %%
df20['Comunidades y Ciudades Autónomas'] = df20['Comunidades y Ciudades Autónomas'].fillna('')
df20['Provincias'] = df20['Provincias'].fillna('')

# %%
df20['Combinada'] = df20['Comunidades y Ciudades Autónomas'].str.cat(df20['Provincias'], sep=' ')

# %%
df20.head(1)
# Out:
#   Diagnóstico principal (CIE10MC)  Total Nacional  \
# 0             0106 COVID-19 U07.1  Total Nacional
#
#   Comunidades y Ciudades Autónomas Provincias         Sexo    Total Combinada
# 0                                              Ambos sexos  1556482

# %%
df20 = df20[df20.columns[[0,4,5,6]]]

# %%
df20
# Out:
#                         Diagnóstico principal (CIE10MC)         Sexo    Total  \
# 0                                   0106 COVID-19 U07.1  Ambos sexos  1556482
# 1                                   0106 COVID-19 U07.1      Hombres   896018
# 2                                   0106 COVID-19 U07.1      Mujeres   660463
# 3                                   0106 COVID-19 U07.1  Ambos sexos    10321
# 4                                   0106 COVID-19 U07.1      Hombres     6655
# ...                                                 ...          ...      ...
# 1744  1008 Otras enfermedades del sistema respirator...      Hombres      592
# 1745  1008 Otras enfermedades del sistema respirator...      Mujeres      583
# 1746  1008 Otras enfermedades del sistema respirator...  Ambos sexos     1730
# 1747  1008 Otras enfermedades del sistema respirator...      Hombres     1114
# 1748  1008 Otras enfermedades del sistema respirator...      Mujeres      615
#
#                     Combinada
# 0
# 1
# 2
# 3     01 Andalucía 04 Almería
# 4     01 Andalucía 04 Almería
# ...                       ...
# 1744                18 Ceuta
# 1745                18 Ceuta
# 1746              19 Melilla
# 1747              19 Melilla
# 1748              19 Melilla
#
# [1749 rows x 4 columns]

# %%
df20['Combinada'].unique()
# Out:
# array([' ', '01 Andalucía 04 Almería', '01 Andalucía 11 Cádiz',
#        '01 Andalucía 14 Córdoba', '01 Andalucía 18 Granada',
#        '01 Andalucía 21 Huelva', '01 Andalucía 23 Jaén',
#        '01 Andalucía 29 Málaga', '01 Andalucía 41 Sevilla',
#        '02 Aragón 22 Huesca', '02 Aragón 44 Teruel',
#        '02 Aragón 50 Zaragoza', '03 Asturias, Principado de ',
#        '04 Balears, Illes ', '05 Canarias 35 Palmas, Las',
#        '05 Canarias 38 Santa Cruz de Tenerife', '06 Cantabria ',
#        '07 Castilla y León 05 Ávila', '07 Castilla y León 09 Burgos',
#        '07 Castilla y León 24 León', '07 Castilla y León 34 Palencia',
#        '07 Castilla y León 37 Salamanca', '07 Castilla y León 40 Segovia',
#        '07 Castilla y León 42 Soria', '07 Castilla y León 47 Valladolid',
#        '07 Castilla y León 49 Zamora',
#        '08 Castilla - La Mancha 02 Albacete',
#        '08 Castilla - La Mancha 13 Ciudad Real',
#        '08 Castilla - La Mancha 16 Cuenca',
#        '08 Castilla - La Mancha 19 Guadalajara',
#        '08 Castilla - La Mancha 45 Toledo', '09 Cataluña 08 Barcelona',
#        '09 Cataluña 17 Girona', '09 Cataluña 25 Lleida',
#        '09 Cataluña 43 Tarragona',
#        '10 Comunitat Valenciana 03 Alicante/Alacant',
#        '10 Comunitat Valenciana 12 Castellón/Castelló',
#        '10 Comunitat Valenciana 46 Valencia/València',
#        '11 Extremadura 06 Badajoz', '11 Extremadura 10 Cáceres',
#        '12 Galicia 15 Coruña, A', '12 Galicia 27 Lugo',
#        '12 Galicia 32 Ourense', '12 Galicia 36 Pontevedra',
#        '13 Madrid, Comunidad de ', '14 Murcia, Región de ',
#        '15 Navarra, Comunidad Foral de ', '16 País Vasco 01 Araba/Álava',
#        '16 País Vasco 48 Bizkaia', '16 País Vasco 20 Gipuzkoa',
#        '17 Rioja, La ', '18 Ceuta ', '19 Melilla '], dtype=object)

# %%
# RENOMBRADO DE COLUMNAS
df20.rename(
    columns = {'Combinada': 'Provincia',
              'Diagnóstico principal (CIE10MC)': 'Diagnóstico',
              'Total': 'Hospitalizaciones'},
    inplace = True
)

# %%
df20 = df20[['Diagnóstico', 'Provincia', 'Sexo', 'Hospitalizaciones']]

# %%
mapeo_combinada = {
    '01 Andalucía 04 Almería': 'Almería',
    '01 Andalucía 11 Cádiz': 'Cádiz',
    '01 Andalucía 14 Córdoba': 'Córdoba',
    '01 Andalucía 18 Granada': "Granada",
    '01 Andalucía 21 Huelva': 'Huelva',
    '01 Andalucía 23 Jaén': 'Jaén',
    '01 Andalucía 29 Málaga': 'Málaga',
    '01 Andalucía 41 Sevilla': 'Sevilla',
    '02 Aragón 22 Huesca': 'Huesca',
    '02 Aragón 44 Teruel': 'Teruel',
    '02 Aragón 50 Zaragoza': 'Zaragoza',
    '03 Asturias, Principado de ': 'Asturias',
    '04 Balears, Illes ': 'Islas Baleares',
    '05 Canarias 35 Palmas, Las': 'Islas Canarias',
    '05 Canarias 38 Santa Cruz de Tenerife': 'Islas Canarias',
    '06 Cantabria ': 'Cantabria',
    '07 Castilla y León 05 Ávila': 'Ávila',
    '07 Castilla y León 09 Burgos': 'Burgos',
    '07 Castilla y León 24 León': 'León',
    '07 Castilla y León 34 Palencia': 'Palencia',
    '07 Castilla y León 37 Salamanca': 'Salamanca',
    '07 Castilla y León 40 Segovia': 'Segovia',
    '07 Castilla y León 42 Soria': 'Soria',
    '07 Castilla y León 47 Valladolid': 'Valladolid',
    '07 Castilla y León 49 Zamora': 'Zamora',
    '08 Castilla - La Mancha 02 Albacete': 'Albacete',
    '08 Castilla - La Mancha 13 Ciudad Real': 'Ciudad Real',
    '08 Castilla - La Mancha 16 Cuenca': 'Cuenca',
    '08 Castilla - La Mancha 19 Guadalajara': 'Guadalajara',
    '08 Castilla - La Mancha 45 Toledo': 'Toledo',
    '09 Cataluña 08 Barcelona': 'Barcelona',
    '09 Cataluña 17 Girona': 'Girona',
    '09 Cataluña 25 Lleida': 'Lleida',
    '09 Cataluña 43 Tarragona': 'Tarragona',
    '10 Comunitat Valenciana 03 Alicante/Alacant': 'Alicante',
    '10 Comunitat Valenciana 12 Castellón/Castelló': 'Castellón',
    '10 Comunitat Valenciana 46 Valencia/València': 'Valencia',
    '11 Extremadura 06 Badajoz': 'Badajoz',
    '11 Extremadura 10 Cáceres': 'Cáceres',
    '12 Galicia 15 Coruña, A': 'A Coruña',
    '12 Galicia 27 Lugo': 'Lugo',
    '12 Galicia 32 Ourense': 'Ourense',
    '12 Galicia 36 Pontevedra': 'Pontevedra',
    '13 Madrid, Comunidad de ': 'Madrid',
    '14 Murcia, Región de ': 'Murcia',
    '15 Navarra, Comunidad Foral de ': 'Navarra',
    '16 País Vasco 01 Araba/Álava': 'Álava',
    '16 País Vasco 48 Bizkaia': 'Bizkaia',
    '16 País Vasco 20 Gipuzkoa': 'Gipuzkoa',
    '17 Rioja, La ': 'La Rioja',
    '18 Ceuta ': 'Ceuta',
    '19 Melilla ': 'Melilla'
}

df20['Provincia'] = df20['Provincia'].map(mapeo_combinada)

# %%
# Crear un filtro para seleccionar filas donde "Provincia" es NaN
filtro = df20['Provincia'].isna()

# Aplicar el filtro para obtener solo las filas donde "Provincia" es NaN
df20_nan_provincia = df20.loc[filtro]

# Mostrar el resultado
df20_nan_provincia
# Out:
#                                             Diagnóstico Provincia  \
# 0                                   0106 COVID-19 U07.1       NaN
# 1                                   0106 COVID-19 U07.1       NaN
# 2                                   0106 COVID-19 U07.1       NaN
# 159   0202 Neoplasias malignas de tráquea, bronquios...       NaN
# 160   0202 Neoplasias malignas de tráquea, bronquios...       NaN
# 161   0202 Neoplasias malignas de tráquea, bronquios...       NaN
# 318   0905 Enfermedades de la circulación pulmonar I...       NaN
# 319   0905 Enfermedades de la circulación pulmonar I...       NaN
# 320   0905 Enfermedades de la circulación pulmonar I...       NaN
# 477   1001 Infecciones agudas de las vías respirator...       NaN
# 478   1001 Infecciones agudas de las vías respirator...       NaN
# 479   1001 Infecciones agudas de las vías respirator...       NaN
# 636                               1002 Neumonía J12-J18       NaN
# 637                               1002 Neumonía J12-J18       NaN
# 638                               1002 Neumonía J12-J18       NaN
# 795      1003 Bronquitis y bronquiolitis agudas J20-J22       NaN
# 796      1003 Bronquitis y bronquiolitis agudas J20-J22       NaN
# 797      1003 Bronquitis y bronquiolitis agudas J20-J22       NaN
# 954   1004 Enfermedad crónica de amígdalas y adenoid...       NaN
# 955   1004 Enfermedad crónica de amígdalas y adenoid...       NaN
# 956   1004 Enfermedad crónica de amígdalas y adenoid...       NaN
# 1113  1005 Otras enfermedades del tracto respiratori...       NaN
# 1114  1005 Otras enfermedades del tracto respiratori...       NaN
# 1115  1005 Otras enfermedades del tracto respiratori...       NaN
# 1272  1006 Enfermedad pulmonar obstructiva crónica y...       NaN
# 1273  1006 Enfermedad pulmonar obstructiva crónica y...       NaN
# 1274  1006 Enfermedad pulmonar obstructiva crónica y...       NaN
# 1431                                      1007 Asma J45       NaN
# 1432                                      1007 Asma J45       NaN
# 1433                                      1007 Asma J45       NaN
# 1590  1008 Otras enfermedades del sistema respirator...       NaN
# 1591  1008 Otras enfermedades del sistema respirator...       NaN
# 1592  1008 Otras enfermedades del sistema respirator...       NaN
#
#              Sexo  Hospitalizaciones
# 0     Ambos sexos            1556482
# 1         Hombres             896018
# 2         Mujeres             660463
# 159   Ambos sexos             309377
# 160       Hombres             223606
# 161       Mujeres              85771
# 318   Ambos sexos             220909
# 319       Hombres             102274
# 320       Mujeres             118635
# 477   Ambos sexos             169633
# 478       Hombres              84837
# 479       Mujeres              84797
# 636   Ambos sexos            2012673
# 637       Hombres            1181688
# 638       Mujeres             830985
# 795   Ambos sexos             362301
# 796       Hombres             166346
# 797       Mujeres             195955
# 954   Ambos sexos              16741
# 955       Hombres               8584
# 956       Mujeres               8157
# 1113  Ambos sexos              63336
# 1114      Hombres              37162
# 1115      Mujeres              26175
# 1272  Ambos sexos             611975
# 1273      Hombres             451932
# 1274      Mujeres             160043
# 1431  Ambos sexos              70531
# 1432      Hombres              18026
# 1433      Mujeres              52505
# 1590  Ambos sexos            1061695
# 1591      Hombres             580118
# 1592      Mujeres             481577

# %%
df20 = df20.dropna()

# %%
df20.head(3)
# Out:
#            Diagnóstico Provincia         Sexo  Hospitalizaciones
# 3  0106 COVID-19 U07.1   Almería  Ambos sexos              10321
# 4  0106 COVID-19 U07.1   Almería      Hombres               6655
# 5  0106 COVID-19 U07.1   Almería      Mujeres               3665

# %%
# CREACIÓN DE OTRA COLUMNA PROVINCIA ID
columna_duplicada = df20['Provincia']
if 'ColumnaDuplicada' in df20.columns:
    df20.drop(columns=['ColumnaDuplicada'], inplace=True)
df20.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df20.rename(
    columns = {'ColumnaDuplicada': 'Provincia_ID'},
    inplace = True
)

# %%
mapeo_provincias = {
    "Álava": 1,
    "Albacete": 2,
    "Alicante": 3,
    "Almería": 4,
    "Ávila": 5,
    "Badajoz": 6,
    "Islas Baleares": 7,
    "Barcelona": 8,
    "Burgos": 9,
    "Cáceres": 10,
    "Cádiz": 11,
    "Castellón": 12,
    "Ciudad Real": 13,
    "Córdoba": 14,
    "A Coruña": 15,
    "Cuenca": 16,
    "Girona": 17,
    "Granada": 18,
    "Guadalajara": 19,
    "Gipuzkoa": 20,
    "Huelva": 21,
    "Huesca": 22,
    "Jaén": 23,
    "León": 24,
    "Lleida": 25,
    "La Rioja": 26,
    "Lugo": 27,
    "Madrid": 28,
    "Málaga": 29,
    "Murcia": 30,
    "Navarra": 31,
    "Ourense": 32,
    "Asturias": 33,
    "Palencia": 34,
    "Islas Canarias": [35, 38],
    "Pontevedra": 36,
    "Salamanca": 37,
    "Cantabria": 39,
    "Segovia": 40,
    "Sevilla": 41,
    "Soria": 42,
    "Tarragona": 43,
    "Teruel": 44,
    "Toledo": 45,
    "Valencia": 46,
    "Valladolid": 47,
    "Bizkaia": 48,
    "Zamora": 49,
    "Zaragoza": 50,
    "Ceuta": 51,
    "Melilla": 52
}

df20['Provincia_ID'] = df20['Provincia_ID'].map(mapeo_provincias)

# %%
df20.head()
# Out:
#            Diagnóstico Provincia Provincia_ID         Sexo  Hospitalizaciones
# 3  0106 COVID-19 U07.1   Almería            4  Ambos sexos              10321
# 4  0106 COVID-19 U07.1   Almería            4      Hombres               6655
# 5  0106 COVID-19 U07.1   Almería            4      Mujeres               3665
# 6  0106 COVID-19 U07.1     Cádiz           11  Ambos sexos              19301
# 7  0106 COVID-19 U07.1     Cádiz           11      Hombres              11491

# %%
df20['Provincia_ID'].isna().sum()
# Out:
# 0

# %%
df20['Diagnóstico'].unique()
# Out:
# array(['0106 COVID-19 U07.1',
#        '0202 Neoplasias malignas de tráquea, bronquios y pulmón  C33-C34',
#        '0905 Enfermedades de la circulación pulmonar I26-I28',
#        '1001 Infecciones agudas de las vías respiratorias superiores y gripe J00-J11',
#        '1002 Neumonía J12-J18',
#        '1003 Bronquitis y bronquiolitis agudas J20-J22',
#        '1004 Enfermedad crónica de amígdalas y adenoides J35',
#        '1005 Otras enfermedades del tracto respiratorio superior J30-J34, J36-J39',
#        '1006 Enfermedad pulmonar obstructiva crónica y bronquiectasias J40-J44, J47',
#        '1007 Asma J45',
#        '1008 Otras enfermedades del sistema respiratorio J60-J99'],
#       dtype=object)

# %%
mapeo_diagnostico = {
    '0106 COVID-19 U07.1':'COVID-19',
    '0202 Neoplasias malignas de tráquea, bronquios y pulmón  C33-C34': "Neoplasia maligna de tráquea, bronquios y pulmón",
    '0905 Enfermedades de la circulación pulmonar I26-I28': "Enfermedades de la circulación pulmonar",
    '1001 Infecciones agudas de las vías respiratorias superiores y gripe J00-J11': 'Infecciones/enfermedades de las vías respiratorias superiores y gripe',
    '1002 Neumonía J12-J18': 'Neumonía',
    '1003 Bronquitis y bronquiolitis agudas J20-J22': 'Otras infecciones de las vias respiratorias inferiores',
    '1004 Enfermedad crónica de amígdalas y adenoides J35': 'Enfermedad crónica de amígdalas',
    '1005 Otras enfermedades del tracto respiratorio superior J30-J34, J36-J39': 'Infecciones/enfermedades de las vías respiratorias superiores y gripe',
    '1006 Enfermedad pulmonar obstructiva crónica y bronquiectasias J40-J44, J47': 'EPOC y bronquitis',
    '1007 Asma J45': 'Asma',
    '1008 Otras enfermedades del sistema respiratorio J60-J99': 'Neumoconiosis, enfermedades pulmonares por agentes externos y otras'
}

df20['Diagnóstico'] = df20['Diagnóstico'].map(mapeo_diagnostico)

# %%
df20.insert(0, 'Año', 2020)

# %%
df20
# Out:
#        Año                                        Diagnóstico Provincia  \
# 3     2020                                           COVID-19   Almería
# 4     2020                                           COVID-19   Almería
# 5     2020                                           COVID-19   Almería
# 6     2020                                           COVID-19     Cádiz
# 7     2020                                           COVID-19     Cádiz
# ...    ...                                                ...       ...
# 1744  2020  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1745  2020  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1746  2020  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1747  2020  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1748  2020  Neumoconiosis, enfermedades pulmonares por age...   Melilla
#
#      Provincia_ID         Sexo  Hospitalizaciones
# 3               4  Ambos sexos              10321
# 4               4      Hombres               6655
# 5               4      Mujeres               3665
# 6              11  Ambos sexos              19301
# 7              11      Hombres              11491
# ...           ...          ...                ...
# 1744           51      Hombres                592
# 1745           51      Mujeres                583
# 1746           52  Ambos sexos               1730
# 1747           52      Hombres               1114
# 1748           52      Mujeres                615
#
# [1716 rows x 6 columns]

# %%
columna_duplicada = df20['Diagnóstico']
if 'ColumnaDuplicada' in df20.columns:
    df20.drop(columns=['ColumnaDuplicada'], inplace=True)
df20.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df20.rename(
    columns = 
    {'ColumnaDuplicada': 'Diagnóstico_ID'
},
inplace = True)

# %%
df20['Diagnóstico_ID'].unique()
# Out:
# array(['COVID-19', 'Neoplasia maligna de tráquea, bronquios y pulmón',
#        'Enfermedades de la circulación pulmonar',
#        'Infecciones/enfermedades de las vías respiratorias superiores y gripe',
#        'Neumonía',
#        'Otras infecciones de las vias respiratorias inferiores',
#        'Enfermedad crónica de amígdalas', 'EPOC y bronquitis', 'Asma',
#        'Neumoconiosis, enfermedades pulmonares por agentes externos y otras'],
#       dtype=object)

# %%
df20
# Out:
#        Año                                        Diagnóstico  \
# 3     2020                                           COVID-19
# 4     2020                                           COVID-19
# 5     2020                                           COVID-19
# 6     2020                                           COVID-19
# 7     2020                                           COVID-19
# ...    ...                                                ...
# 1744  2020  Neumoconiosis, enfermedades pulmonares por age...
# 1745  2020  Neumoconiosis, enfermedades pulmonares por age...
# 1746  2020  Neumoconiosis, enfermedades pulmonares por age...
# 1747  2020  Neumoconiosis, enfermedades pulmonares por age...
# 1748  2020  Neumoconiosis, enfermedades pulmonares por age...
#
#                                          Diagnóstico_ID Provincia  \
# 3                                              COVID-19   Almería
# 4                                              COVID-19   Almería
# 5                                              COVID-19   Almería
# 6                                              COVID-19     Cádiz
# 7                                              COVID-19     Cádiz
# ...                                                 ...       ...
# 1744  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1745  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1746  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1747  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1748  Neumoconiosis, enfermedades pulmonares por age...   Melilla
#
#      Provincia_ID         Sexo  Hospitalizaciones
# 3               4  Ambos sexos              10321
# 4               4      Hombres               6655
# 5               4      Mujeres               3665
# 6              11  Ambos sexos              19301
# 7              11      Hombres              11491
# ...           ...          ...                ...
# 1744           51      Hombres                592
# 1745           51      Mujeres                583
# 1746           52  Ambos sexos               1730
# 1747           52      Hombres               1114
# 1748           52      Mujeres                615
#
# [1716 rows x 7 columns]

# %%
mapeo_diagnostico = {
    'Neoplasia maligna de tráquea, bronquios y pulmón': 1,
    'Enfermedades de la circulación pulmonar':2,
    'Enfermedad crónica de amígdalas': 3,
    'Neumonía': 4,
    'Asma': 5,
    'EPOC y bronquitis': 6,
    'Infecciones/enfermedades de las vías respiratorias superiores y gripe': 7,
    'Otras infecciones de las vias respiratorias inferiores': 8,
    'Neumoconiosis, enfermedades pulmonares por agentes externos y otras': 9,
    'COVID-19': 10
}

df20['Diagnóstico_ID'] = df20['Diagnóstico_ID'].map(mapeo_diagnostico)

# %%
df20 = df20[df20['Sexo'] != 'Ambos sexos']

# %%
df20 = df20.reset_index()

# %%
df20.drop('index', axis=1, inplace=True)

# %%
df20
# Out:
#        Año                                        Diagnóstico  Diagnóstico_ID  \
# 0     2020                                           COVID-19              10
# 1     2020                                           COVID-19              10
# 2     2020                                           COVID-19              10
# 3     2020                                           COVID-19              10
# 4     2020                                           COVID-19              10
# ...    ...                                                ...             ...
# 1139  2020  Neumoconiosis, enfermedades pulmonares por age...               9
# 1140  2020  Neumoconiosis, enfermedades pulmonares por age...               9
# 1141  2020  Neumoconiosis, enfermedades pulmonares por age...               9
# 1142  2020  Neumoconiosis, enfermedades pulmonares por age...               9
# 1143  2020  Neumoconiosis, enfermedades pulmonares por age...               9
#
#      Provincia Provincia_ID     Sexo  Hospitalizaciones
# 0      Almería            4  Hombres               6655
# 1      Almería            4  Mujeres               3665
# 2        Cádiz           11  Hombres              11491
# 3        Cádiz           11  Mujeres               7810
# 4      Córdoba           14  Hombres              10035
# ...        ...          ...      ...                ...
# 1139  La Rioja           26  Mujeres               3917
# 1140     Ceuta           51  Hombres                592
# 1141     Ceuta           51  Mujeres                583
# 1142   Melilla           52  Hombres               1114
# 1143   Melilla           52  Mujeres                615
#
# [1144 rows x 7 columns]

# %%
df20.to_csv("df20.csv", index=False, encoding="iso-8859-1")
