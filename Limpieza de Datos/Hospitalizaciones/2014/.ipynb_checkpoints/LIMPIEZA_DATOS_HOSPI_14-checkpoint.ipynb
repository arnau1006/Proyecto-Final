# %% [markdown]
# # Limpieza de datos de hospitalizaciones 2014

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df14 = pd.read_csv("1-2014.csv", delimiter= ";", encoding = "latin1")

df14.columns = df14.columns.str.strip()

# %%
# Mostrar los nombres de columnas para verificar
print("Columnas de df14:", df14.columns)
# Out:
# Columnas de df14: Index(['Diagnóstico principal (CIE9MC)',
#        'Provincia, Comunidad y Ciudad autónoma de residencia', 'Sexo',
#        'Total'],
#       dtype='object')

# %%
df14.shape
# Out:
# (1716, 4)

# %%
# LIMPIEZA COLUMNA TOTAL
df14['Total'] = df14['Total'].str.replace('.', '')
df14['Total'] = pd.to_numeric(df14['Total'])

# %%
df14['Total'].isnull().sum()
# Out:
# 38

# %%
df14['Total'] = df14['Total'].fillna(0)

# %%
df14['Total'] = df14['Total'].astype(int)

# %%
df14.dtypes
# Out:
# Diagnóstico principal (CIE9MC)                          object
# Provincia, Comunidad y Ciudad autónoma de residencia    object
# Sexo                                                    object
# Total                                                    int32
# dtype: object

# %%
# RENOMBRADO DE COLUMNAS
df14.rename(
    columns = {'Provincia, Comunidad y Ciudad autónoma de residencia': 'Provincia',
              'Diagnóstico principal (CIE9MC)': 'Diagnóstico',
              'Total': 'Hospitalizaciones'},
    inplace = True
)

# %%
mapeo_provincias2 = {
    "Araba/Álava": "Álava",
    "Albacete": "Albacete",
    "Alicante/Alacant": "Alicante",
    "Almería": "Almería",
    "Ávila": "Ávila",
    "Badajoz": "Badajoz",
    "BALEARS, ILLES": "Islas Baleares",
    "Barcelona": "Barcelona",
    "Burgos": "Burgos",
    "Cáceres": "Cáceres",
    "Cádiz": "Cádiz",
    "Castellón/Castelló": "Castellón",
    "Ciudad Real": "Ciudad Real",
    "Córdoba": "Córdoba",
    "Coruña, A": "A Coruña",
    "Cuenca": "Cuenca",
    "Girona": "Girona",
    "Granada": "Granada",
    "Guadalajara": "Guadalajara",
    "Gipuzkoa": "Gipuzkoa",
    "Huelva": "Huelva",
    "Huesca": "Huesca",
    "Jaén": "Jaén",
    "León": "León",
    "Lleida": "Lleida",
    "RIOJA, LA": "La Rioja",
    "Lugo": "Lugo",
    "MADRID, COMUNIDAD DE": "Madrid",
    "Málaga": "Málaga",
    "MURCIA, REGIÓN DE": "Murcia",
    "NAVARRA, COMUNIDAD FORAL DE": "Navarra",
    "Ourense": "Ourense",
    "ASTURIAS, PRINCIPADO DE": "Asturias",
    "Palencia": "Palencia",
    "Palmas, Las": "Islas Canarias",
    "Pontevedra": "Pontevedra",
    "Salamanca": "Salamanca",
    "Santa Cruz de Tenerife": "Islas Canarias",
    "CANTABRIA": "Cantabria",
    "Segovia": "Segovia",
    "Sevilla": "Sevilla",
    "Soria": "Soria",
    "Tarragona": "Tarragona",
    "Teruel": "Teruel",
    "Toledo": "Toledo",
    "Valencia/València": "Valencia",
    "Valladolid": "Valladolid",
    "Bizkaia": "Bizkaia",
    "Zamora": "Zamora",
    "Zaragoza": "Zaragoza",
    "Ceuta": "Ceuta",
    "Melilla": "Melilla"
}

df14['Provincia'] = df14['Provincia'].map(mapeo_provincias2)

# %%
df14['Provincia'].unique()
# Out:
# array(['Almería', 'Cádiz', 'Córdoba', 'Granada', 'Huelva', 'Jaén',
#        'Málaga', 'Sevilla', 'Huesca', 'Teruel', 'Zaragoza', 'Asturias',
#        'Islas Baleares', 'Islas Canarias', 'Cantabria', 'Ávila', 'Burgos',
#        'León', 'Palencia', 'Salamanca', 'Segovia', 'Soria', 'Valladolid',
#        'Zamora', 'Albacete', 'Ciudad Real', 'Cuenca', 'Guadalajara',
#        'Toledo', 'Barcelona', 'Girona', 'Lleida', 'Tarragona', 'Alicante',
#        'Castellón', 'Valencia', 'Badajoz', 'Cáceres', 'A Coruña', 'Lugo',
#        'Ourense', 'Pontevedra', 'Madrid', 'Murcia', nan, 'Álava',
#        'Bizkaia', 'Gipuzkoa', 'La Rioja', 'Ceuta', 'Melilla'],
#       dtype=object)

# %%
# Crear un filtro para seleccionar filas donde "Provincia" es NaN
filtro = df14['Provincia'].isna()

# Aplicar el filtro para obtener solo las filas donde "Provincia" es NaN
df14_nan_provincia = df14.loc[filtro]

# Mostrar el resultado
df14_nan_provincia
# Out:
#                                             Diagnóstico Provincia  \
# 135   162 Neoplasia maligna de tráquea, bronquios y ...       NaN
# 136   162 Neoplasia maligna de tráquea, bronquios y ...       NaN
# 137   162 Neoplasia maligna de tráquea, bronquios y ...       NaN
# 291   415-417 VII.5 ENFERMEDADES DE LA CIRCULACIÓN P...       NaN
# 292   415-417 VII.5 ENFERMEDADES DE LA CIRCULACIÓN P...       NaN
# 293   415-417 VII.5 ENFERMEDADES DE LA CIRCULACIÓN P...       NaN
# 447                466 Bronquitis y bronquiolitis aguda       NaN
# 448                466 Bronquitis y bronquiolitis aguda       NaN
# 449                466 Bronquitis y bronquiolitis aguda       NaN
# 603     474 Enfermedad crónica de amígdalas y adenoides       NaN
# 604     474 Enfermedad crónica de amígdalas y adenoides       NaN
# 605     474 Enfermedad crónica de amígdalas y adenoides       NaN
# 759   Resto (460-478) Otras infecciones respiratoria...       NaN
# 760   Resto (460-478) Otras infecciones respiratoria...       NaN
# 761   Resto (460-478) Otras infecciones respiratoria...       NaN
# 915                                    480-486 Neumonía       NaN
# 916                                    480-486 Neumonía       NaN
# 917                                    480-486 Neumonía       NaN
# 1071                                      487-488 Gripe       NaN
# 1072                                      487-488 Gripe       NaN
# 1073                                      487-488 Gripe       NaN
# 1227  490-492,494,496 Enfermedad pulmonar obstructiv...       NaN
# 1228  490-492,494,496 Enfermedad pulmonar obstructiv...       NaN
# 1229  490-492,494,496 Enfermedad pulmonar obstructiv...       NaN
# 1383                                           493 Asma       NaN
# 1384                                           493 Asma       NaN
# 1385                                           493 Asma       NaN
# 1539  Resto (490-496) Otras enfermedades asociadas a...       NaN
# 1540  Resto (490-496) Otras enfermedades asociadas a...       NaN
# 1541  Resto (490-496) Otras enfermedades asociadas a...       NaN
# 1695  500-519 VIII.4 NEUMOCONIOSIS, ENFERMEDADES PUL...       NaN
# 1696  500-519 VIII.4 NEUMOCONIOSIS, ENFERMEDADES PUL...       NaN
# 1697  500-519 VIII.4 NEUMOCONIOSIS, ENFERMEDADES PUL...       NaN
#
#              Sexo  Hospitalizaciones
# 135   Ambos sexos              15981
# 136       Hombres              12147
# 137       Mujeres               3834
# 291   Ambos sexos               9149
# 292       Hombres               4028
# 293       Mujeres               5121
# 447   Ambos sexos              17222
# 448       Hombres               7453
# 449       Mujeres               9769
# 603   Ambos sexos               1578
# 604       Hombres                835
# 605       Mujeres                744
# 759   Ambos sexos               6514
# 760       Hombres               3800
# 761       Mujeres               2714
# 915   Ambos sexos              38280
# 916       Hombres              23022
# 917       Mujeres              15258
# 1071  Ambos sexos               3761
# 1072      Hombres               2057
# 1073      Mujeres               1704
# 1227  Ambos sexos              33770
# 1228      Hombres              25801
# 1229      Mujeres               7968
# 1383  Ambos sexos              10422
# 1384      Hombres               2987
# 1385      Mujeres               7434
# 1539  Ambos sexos                 44
# 1540      Hombres                 31
# 1541      Mujeres                 13
# 1695  Ambos sexos              50865
# 1696      Hombres              27601
# 1697      Mujeres              23264

# %%
df14 = df14.dropna()

# %%
# CREACIÓN DE OTRA COLUMNA PROVINCIA ID
columna_duplicada = df14['Provincia']
if 'ColumnaDuplicada' in df14.columns:
    df14.drop(columns=['ColumnaDuplicada'], inplace=True)
df14.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df14.rename(
    columns = {'ColumnaDuplicada': 'Provincia_ID'},
    inplace = True
)

# %%
mapeo_provincias = {
    "Álava": 1,
    "Albacete": 2,
    "Alicante": 3,
    "Almería": 4,
    "Ávila": 5,
    "Badajoz": 6,
    "Islas Baleares": 7,
    "Barcelona": 8,
    "Burgos": 9,
    "Cáceres": 10,
    "Cádiz": 11,
    "Castellón": 12,
    "Ciudad Real": 13,
    "Córdoba": 14,
    "A Coruña": 15,
    "Cuenca": 16,
    "Girona": 17,
    "Granada": 18,
    "Guadalajara": 19,
    "Gipuzkoa": 20,
    "Huelva": 21,
    "Huesca": 22,
    "Jaén": 23,
    "León": 24,
    "Lleida": 25,
    "La Rioja": 26,
    "Lugo": 27,
    "Madrid": 28,
    "Málaga": 29,
    "Murcia": 30,
    "Navarra": 31,
    "Ourense": 32,
    "Asturias": 33,
    "Palencia": 34,
    "Islas Canarias": [35, 38],
    "Pontevedra": 36,
    "Salamanca": 37,
    "Cantabria": 39,
    "Segovia": 40,
    "Sevilla": 41,
    "Soria": 42,
    "Tarragona": 43,
    "Teruel": 44,
    "Toledo": 45,
    "Valencia": 46,
    "Valladolid": 47,
    "Bizkaia": 48,
    "Zamora": 49,
    "Zaragoza": 50,
    "Ceuta": 51,
    "Melilla": 52
}

df14['Provincia_ID'] = df14['Provincia_ID'].map(mapeo_provincias)

# %%
df14.head()
# Out:
#                                          Diagnóstico Provincia Provincia_ID  \
# 0  162 Neoplasia maligna de tráquea, bronquios y ...   Almería            4
# 1  162 Neoplasia maligna de tráquea, bronquios y ...   Almería            4
# 2  162 Neoplasia maligna de tráquea, bronquios y ...   Almería            4
# 3  162 Neoplasia maligna de tráquea, bronquios y ...     Cádiz           11
# 4  162 Neoplasia maligna de tráquea, bronquios y ...     Cádiz           11
#
#           Sexo  Hospitalizaciones
# 0  Ambos sexos               4532
# 1      Hombres               3806
# 2      Mujeres                726
# 3  Ambos sexos               7575
# 4      Hombres               6227

# %%
df14['Diagnóstico'].unique()
# Out:
# array(['162 Neoplasia maligna de tráquea, bronquios y pulmón',
#        '415-417 VII.5 ENFERMEDADES DE LA CIRCULACIÓN PULMONAR',
#        '466 Bronquitis y bronquiolitis aguda',
#        '474 Enfermedad crónica de amígdalas y adenoides',
#        'Resto (460-478) Otras infecciones respiratorias agudas y otras enfermedades del tracto respiratorio superior',
#        '480-486 Neumonía', '487-488 Gripe',
#        '490-492,494,496 Enfermedad pulmonar obstructiva crónica y bronquitis',
#        '493 Asma',
#        'Resto (490-496) Otras enfermedades asociadas a enfermedad pulmonar obstructiva crónica',
#        '500-519 VIII.4 NEUMOCONIOSIS, ENFERMEDADES PULMONARES OCASIONADAS POR AGENTES EXTERNOS Y OTRAS ENF. DEL APARATO RESPIRATORIO'],
#       dtype=object)

# %%
# SIMPLIFICACIÓN DE NOMBRES EN COLUMNA DIAGNÓSTICO
mapeo_diagnostico = {
    "162 Neoplasia maligna de tráquea, bronquios y pulmón": "Neoplasia maligna de tráquea, bronquios y pulmón",
    "415-417 VII.5 ENFERMEDADES DE LA CIRCULACIÓN PULMONAR": "Enfermedades de la circulación pulmonar",
    "466 Bronquitis y bronquiolitis aguda": "Otras infecciones de las vias respiratorias inferiores",
    "474 Enfermedad crónica de amígdalas y adenoides": "Enfermedad crónica de amígdalas",
    "Resto (460-478) Otras infecciones respiratorias agudas y otras enfermedades del tracto respiratorio superior": "Infecciones/enfermedades de las vías respiratorias superiores y gripe",
    "480-486 Neumonía": "Neumonía",
    "487-488 Gripe": "Infecciones/enfermedades de las vías respiratorias superiores y gripe",
    "490-492,494,496 Enfermedad pulmonar obstructiva crónica y bronquitis": "EPOC y bronquitis",
    "493 Asma": "Asma",
    "Resto (490-496) Otras enfermedades asociadas a enfermedad pulmonar obstructiva crónica": "Neumoconiosis, enfermedades pulmonares por agentes externos y otras",
    "500-519 VIII.4 NEUMOCONIOSIS, ENFERMEDADES PULMONARES OCASIONADAS POR AGENTES EXTERNOS Y OTRAS ENF. DEL APARATO RESPIRATORIO": "Neumoconiosis, enfermedades pulmonares por agentes externos y otras"
}

df14['Diagnóstico'] = df14['Diagnóstico'].map(mapeo_diagnostico)

# %%
df14.insert(0, 'Año', 2014)

# %%
df14
# Out:
#        Año                                        Diagnóstico Provincia  \
# 0     2014   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 1     2014   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 2     2014   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 3     2014   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# 4     2014   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# ...    ...                                                ...       ...
# 1711  2014  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1712  2014  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1713  2014  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1714  2014  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1715  2014  Neumoconiosis, enfermedades pulmonares por age...   Melilla
#
#      Provincia_ID         Sexo  Hospitalizaciones
# 0               4  Ambos sexos               4532
# 1               4      Hombres               3806
# 2               4      Mujeres                726
# 3              11  Ambos sexos               7575
# 4              11      Hombres               6227
# ...           ...          ...                ...
# 1711           51      Hombres                588
# 1712           51      Mujeres                604
# 1713           52  Ambos sexos               1713
# 1714           52      Hombres                825
# 1715           52      Mujeres                888
#
# [1683 rows x 6 columns]

# %%
df14 = df14[df14['Sexo'] != 'Ambos sexos']

# %%
df14
# Out:
#        Año                                        Diagnóstico Provincia  \
# 1     2014   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 2     2014   Neoplasia maligna de tráquea, bronquios y pulmón   Almería
# 4     2014   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# 5     2014   Neoplasia maligna de tráquea, bronquios y pulmón     Cádiz
# 7     2014   Neoplasia maligna de tráquea, bronquios y pulmón   Córdoba
# ...    ...                                                ...       ...
# 1709  2014  Neumoconiosis, enfermedades pulmonares por age...  La Rioja
# 1711  2014  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1712  2014  Neumoconiosis, enfermedades pulmonares por age...     Ceuta
# 1714  2014  Neumoconiosis, enfermedades pulmonares por age...   Melilla
# 1715  2014  Neumoconiosis, enfermedades pulmonares por age...   Melilla
#
#      Provincia_ID     Sexo  Hospitalizaciones
# 1               4  Hombres               3806
# 2               4  Mujeres                726
# 4              11  Hombres               6227
# 5              11  Mujeres               1348
# 7              14  Hombres               2949
# ...           ...      ...                ...
# 1709           26  Mujeres               7487
# 1711           51  Hombres                588
# 1712           51  Mujeres                604
# 1714           52  Hombres                825
# 1715           52  Mujeres                888
#
# [1122 rows x 6 columns]

# %%
df14["Diagnóstico"].unique()
# Out:
# array(['Neoplasia maligna de tráquea, bronquios y pulmón',
#        'Enfermedades de la circulación pulmonar',
#        'Otras infecciones de las vias respiratorias inferiores',
#        'Enfermedad crónica de amígdalas',
#        'Infecciones/enfermedades de las vías respiratorias superiores y gripe',
#        'Neumonía', 'EPOC y bronquitis', 'Asma',
#        'Neumoconiosis, enfermedades pulmonares por agentes externos y otras'],
#       dtype=object)

# %%
# CREACIÓN COLUMNA DIAGNÓSTICO ID
columna_duplicada = df14['Diagnóstico']
if 'ColumnaDuplicada' in df14.columns:
    df14.drop(columns=['ColumnaDuplicada'], inplace=True)
df14.insert(2, 'ColumnaDuplicada', columna_duplicada)

# %%
df14.rename(
    columns = {'ColumnaDuplicada': 'Diagnóstico_ID'},
    inplace = True
)
# Out:
# C:\Users\crisg\AppData\Local\Temp\ipykernel_35896\2474925014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14.rename(

# %%
mapeo_diagnostico = {
    'Neoplasia maligna de tráquea, bronquios y pulmón': 1,
    'Enfermedades de la circulación pulmonar':2,
    'Enfermedad crónica de amígdalas': 3,
    'Neumonía': 4,
    'Asma': 5,
    'EPOC y bronquitis': 6,
    'Infecciones/enfermedades de las vías respiratorias superiores y gripe': 7,
    'Otras infecciones de las vias respiratorias inferiores': 8,
    'Neumoconiosis, enfermedades pulmonares por agentes externos y otras': 9
}

df14['Diagnóstico_ID'] = df14['Diagnóstico_ID'].map(mapeo_diagnostico)
# Out:
# C:\Users\crisg\AppData\Local\Temp\ipykernel_35896\735078104.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14['Diagnóstico_ID'] = df14['Diagnóstico_ID'].map(mapeo_diagnostico)

# %%
df14 = df14.reset_index()

# %%
df14.drop('index', axis=1, inplace=True)

# %%
df14
# Out:
#        Año                                        Diagnóstico  Diagnóstico_ID  \
# 0     2014   Neoplasia maligna de tráquea, bronquios y pulmón               1
# 1     2014   Neoplasia maligna de tráquea, bronquios y pulmón               1
# 2     2014   Neoplasia maligna de tráquea, bronquios y pulmón               1
# 3     2014   Neoplasia maligna de tráquea, bronquios y pulmón               1
# 4     2014   Neoplasia maligna de tráquea, bronquios y pulmón               1
# ...    ...                                                ...             ...
# 1117  2014  Neumoconiosis, enfermedades pulmonares por age...               9
# 1118  2014  Neumoconiosis, enfermedades pulmonares por age...               9
# 1119  2014  Neumoconiosis, enfermedades pulmonares por age...               9
# 1120  2014  Neumoconiosis, enfermedades pulmonares por age...               9
# 1121  2014  Neumoconiosis, enfermedades pulmonares por age...               9
#
#      Provincia Provincia_ID     Sexo  Hospitalizaciones
# 0      Almería            4  Hombres               3806
# 1      Almería            4  Mujeres                726
# 2        Cádiz           11  Hombres               6227
# 3        Cádiz           11  Mujeres               1348
# 4      Córdoba           14  Hombres               2949
# ...        ...          ...      ...                ...
# 1117  La Rioja           26  Mujeres               7487
# 1118     Ceuta           51  Hombres                588
# 1119     Ceuta           51  Mujeres                604
# 1120   Melilla           52  Hombres                825
# 1121   Melilla           52  Mujeres                888
#
# [1122 rows x 7 columns]

# %%
df14.to_csv("df14.csv", index=False, encoding="iso-8859-1")
