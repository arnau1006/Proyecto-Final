# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as snf
import seaborn as sns

# %%
data_as = pd.read_csv("As_DD_2012.csv", delimiter=";")
data_bap = pd.read_csv("B(a)P_DD_2012.csv", delimiter=";")
data_cd = pd.read_csv("Cd_DD_2012.csv", delimiter=";")
data_ni = pd.read_csv("Ni_DD_2012.csv", delimiter=";")
data_pb = pd.read_csv("Pb_DD_2012.csv", delimiter=";")
data_pm10 = pd.read_csv("PM10_DD_2012.csv", delimiter=";")
data_pm25 = pd.read_csv("PM2.5_DD_2012.csv", delimiter=";")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_12 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_12.MEDIAANUAL_EMISION = result_12.MEDIAANUAL_EMISION.round(4)

# %%
result_12
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2012              0.3552
# 1        As          3  2012              0.2681
# 2        As          4  2012              0.5523
# 3        As          6  2012              0.3676
# 4        As          7  2012              1.1795
# ..      ...        ...   ...                 ...
# 199      Pb         45  2012              0.0025
# 200      Pb         46  2012              0.0034
# 201      Pb         47  2012              0.0101
# 202      Pb         48  2012              0.0498
# 203      Pb         49  2012              0.0018
#
# [204 rows x 4 columns]

# %%
data_as = pd.read_csv("As_2013_DD.csv", delimiter=";")
data_bap = pd.read_csv("BaP_2013_DD.csv", delimiter=";")
data_cd = pd.read_csv("Cd_2013_DD.csv", delimiter=";")
data_ni = pd.read_csv("Ni_2013_DD.csv", delimiter=";")
data_pb = pd.read_csv("Pb_2013_DD.csv", delimiter=";")
data_pm10 = pd.read_csv("PM10_2013_DD.csv", delimiter=";")
data_pm25 = pd.read_csv("PM2.5_2013_DD.csv", delimiter=";")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_13 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_13.MEDIAANUAL_EMISION = result_13.MEDIAANUAL_EMISION.round(4)

# %%
result_13
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2013              0.2968
# 1        As          2  2013              0.7000
# 2        As          3  2013              0.1855
# 3        As          4  2013              0.4211
# 4        As          6  2013              0.3231
# ..      ...        ...   ...                 ...
# 221      Pb         45  2013              0.0013
# 222      Pb         46  2013              0.0019
# 223      Pb         47  2013              0.0585
# 224      Pb         48  2013              0.0375
# 225      Pb         50  2013              0.0025
#
# [226 rows x 4 columns]

# %%
data_as = pd.read_csv("As_DD_2014.csv")
data_bap = pd.read_csv("B(a)P_DD_2014.csv")
data_cd = pd.read_csv("Cd_DD_2014.csv")
data_ni = pd.read_csv("Ni_DD_2014.csv")
data_pb = pd.read_csv("Pb_DD_2014.csv")
data_pm10 = pd.read_csv("PM10_DD_2014.csv")
data_pm25 = pd.read_csv("PM2.5_DD_2014.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 data_as = pd.read_csv("As_DD_2014.csv")
#       2 data_bap = pd.read_csv("B(a)P_DD_2014.csv")
#       3 data_cd = pd.read_csv("Cd_DD_2014.csv")
#
# ...

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_14 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_14.MEDIAANUAL_EMISION = result_14.MEDIAANUAL_EMISION.round(4)

# %%
result_14

# %%
data_as = pd.read_csv("As_DD_2015.csv")
data_bap = pd.read_csv("B(a)P_DD_2015.csv")
data_cd = pd.read_csv("Cd_DD_2015.csv")
data_ni = pd.read_csv("Ni_DD_2015.csv")
data_pb = pd.read_csv("Pb_DD_2015.csv")
data_pm10 = pd.read_csv("PM10_DD_2015.csv")
data_pm25 = pd.read_csv("PM2.5_DD_2015.csv")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_15 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_15.MEDIAANUAL_EMISION = result_15.MEDIAANUAL_EMISION.round(4)

# %%
result_15
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2013              0.2968
# 1        As          2  2013              0.7000
# 2        As          3  2013              0.1855
# 3        As          4  2013              0.4211
# 4        As          6  2013              0.3231
# ..      ...        ...   ...                 ...
# 221      Pb         45  2013              0.0013
# 222      Pb         46  2013              0.0019
# 223      Pb         47  2013              0.0585
# 224      Pb         48  2013              0.0375
# 225      Pb         50  2013              0.0025
#
# [226 rows x 4 columns]

# %%
data_as = pd.read_csv("As_DD_2016.csv")
data_bap = pd.read_csv("B(a)P_DD_2016.csv")
data_cd = pd.read_csv("Cd_DD_2016.csv")
data_ni = pd.read_csv("Ni_DD_2016.csv")
data_pb = pd.read_csv("Pb_DD_2016.csv")
data_pm10 = pd.read_csv("PM10_DD_2016.csv")
data_pm25 = pd.read_csv("PM25_DD_2016.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 data_as = pd.read_csv("As_DD_2016.csv")
#       2 data_bap = pd.read_csv("B(a)P_DD_2016.csv")
#       3 data_cd = pd.read_csv("Cd_DD_2016.csv")
#
# ...

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_16 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_16.MEDIAANUAL_EMISION = result_16.MEDIAANUAL_EMISION.round(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 result_16.MEDIAANUAL_EMISION = result_16.MEDIAANUAL_EMISION.round(4)
#
# NameError: name 'result_16' is not defined

# %%
result_16
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 result_16
#
# NameError: name 'result_16' is not defined

# %%
data_as = pd.read_csv("As_DD_2017.csv", delimiter = ";")
data_bap = pd.read_csv("B(a)P_DD_2017.csv", delimiter = ";")
data_cd = pd.read_csv("Cd_DD_2017.csv", delimiter = ";")
data_ni = pd.read_csv("Ni_DD_2017.csv", delimiter = ";")
data_pb = pd.read_csv("Pb_DD_2017.csv", delimiter = ";")
data_pm10 = pd.read_csv("PM10_DD_2017.csv", delimiter = ";")
data_pm25 = pd.read_csv("PM2.5_DD_2017.csv", delimiter = ";")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_17 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_17.MEDIAANUAL_EMISION = result_17.MEDIAANUAL_EMISION.round(4)

# %%
result_17
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2013              0.2968
# 1        As          2  2013              0.7000
# 2        As          3  2013              0.1855
# 3        As          4  2013              0.4211
# 4        As          6  2013              0.3231
# ..      ...        ...   ...                 ...
# 221      Pb         45  2013              0.0013
# 222      Pb         46  2013              0.0019
# 223      Pb         47  2013              0.0585
# 224      Pb         48  2013              0.0375
# 225      Pb         50  2013              0.0025
#
# [226 rows x 4 columns]

# %%
data_as = pd.read_csv("As_DD_2018.csv", delimiter = ";")
data_bap = pd.read_csv("B(a)P_DD_2018.csv", delimiter = ";")
data_cd = pd.read_csv("Cd_DD_2018.csv", delimiter = ";")
data_ni = pd.read_csv("Ni_DD_2018.csv", delimiter = ";")
data_pb = pd.read_csv("Pb_DD_2018.csv", delimiter = ";")
data_pm10 = pd.read_csv("PM10_DD_2018.csv", delimiter = ";")
data_pm25 = pd.read_csv("PM2.5_DD_2018.csv", delimiter = ";")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_18 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_18.MEDIAANUAL_EMISION = result_18.MEDIAANUAL_EMISION.round(4)

# %%
result_18
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2018              0.3618
# 1        As          2  2018              0.3485
# 2        As          3  2018              0.2237
# 3        As          4  2018              0.2607
# 4        As          6  2018              0.3903
# ..      ...        ...   ...                 ...
# 267      Pb         41  2018              0.0026
# 268      Pb         43  2018              0.0025
# 269      Pb         45  2018              0.0014
# 270      Pb         46  2018              0.0103
# 271      Pb         48  2018              0.0209
#
# [272 rows x 4 columns]

# %%
data_as = pd.read_csv("As_DD_2019.csv", delimiter = ";")
data_bap = pd.read_csv("BaP_DD_2019.csv", delimiter = ";")
data_cd = pd.read_csv("Cd_DD_2019.csv", delimiter = ";")
data_ni = pd.read_csv("Ni_DD_2019.csv", delimiter = ";")
data_pb = pd.read_csv("Pb_DD_2019.csv", delimiter = ";")
data_pm10 = pd.read_csv("PM10_DD_2019.csv", delimiter = ";")
data_pm25 = pd.read_csv("PM25_DD_2019.csv", delimiter = ";")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_19 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_19.MEDIAANUAL_EMISION = result_19.MEDIAANUAL_EMISION.round(4)

# %%
result_19
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2019              0.3449
# 1        As          2  2019              0.5513
# 2        As          3  2019              0.3643
# 3        As          4  2019              0.5208
# 4        As          6  2019              0.4173
# ..      ...        ...   ...                 ...
# 231      Pb         43  2019              0.0025
# 232      Pb         45  2019              0.0013
# 233      Pb         46  2019              0.0102
# 234      Pb         47  2019              0.0124
# 235      Pb         48  2019              0.0189
#
# [236 rows x 4 columns]

# %%
data_as = pd.read_csv("As_DD_2020.csv", delimiter = ";")
data_bap = pd.read_csv("B(a)P_DD_2020.csv", delimiter = ";")
data_cd = pd.read_csv("Cd_DD_2020.csv", delimiter = ";")
data_ni = pd.read_csv("Ni_DD_2020.csv", delimiter = ";")
data_pb = pd.read_csv("Pb_DD_2020.csv", delimiter = ";")
data_pm10 = pd.read_csv("PM10_DD_2020.csv", delimiter = ";")
data_pm25 = pd.read_csv("PM2.5_DD_2020.csv", delimiter = ";")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_20 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_20.MEDIAANUAL_EMISION = result_20.MEDIAANUAL_EMISION.round(4)

# %%
result_20
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2020              0.3183
# 1        As          2  2020              0.4175
# 2        As          3  2020              0.7493
# 3        As          4  2020              0.4190
# 4        As          6  2020              0.4149
# ..      ...        ...   ...                 ...
# 255      Pb         45  2020              0.0011
# 256      Pb         46  2020              0.0103
# 257      Pb         47  2020              0.0229
# 258      Pb         48  2020              0.0140
# 259      Pb         50  2020              0.0055
#
# [260 rows x 4 columns]

# %%
data_as = pd.read_csv("As_DD_2021.csv", delimiter = ";")
data_bap = pd.read_csv("BaP_DD_2021.csv", delimiter = ";")
data_cd = pd.read_csv("Cd_DD_2021.csv", delimiter = ";")
data_ni = pd.read_csv("Ni_DD_2021.csv", delimiter = ";")
data_pb = pd.read_csv("Pb_DD_2021.csv", delimiter = ";")
data_pm10 = pd.read_csv("PM10_DD_2021.csv", delimiter = ";")
data_pm25 = pd.read_csv("PM25_DD_2021.csv", delimiter = ";")

# %%
data_as["EMISION"] = "As"
data_bap["EMISION"] = "BaP"
data_cd["EMISION"] = "Cd"
data_ni["EMISION"] = "Ni"
data_pb["EMISION"] = "Pb"
data_pm10["EMISION"] = "PM10"
data_pm25["EMISION"] = "PM25"

# %%
all_data = pd.concat([data_as, data_bap, data_cd, data_ni, data_pb, data_pm10, data_pm25], ignore_index=True)

# %%
day_columns = [f'D{i:02}' for i in range(1, 32)]
all_data[day_columns] = all_data[day_columns].interpolate(axis=1, method='linear', limit_direction='both')

# %%
medias = []
for i in range(len(all_data)):
    row = all_data.loc[i, day_columns]
    if row.count() >= 15:
        valor_media = row.mean()
    else:
        valor_media = np.nan
    medias.append(valor_media)

# %%
all_data["MEDIA MENSUAL"] = medias

# %%
result_21 = all_data.groupby(["EMISION", "PROVINCIA", "ANNO"]).agg(
    MEDIAANUAL_EMISION=pd.NamedAgg(column="MEDIA MENSUAL", aggfunc="mean")
).reset_index()

# %%
result_21.MEDIAANUAL_EMISION = result_21.MEDIAANUAL_EMISION.round(4)

# %%
result_21
# Out:
#     EMISION  PROVINCIA  ANNO  MEDIAANUAL_EMISION
# 0        As          1  2021              0.3303
# 1        As          2  2021              0.3981
# 2        As          3  2021              0.2227
# 3        As          4  2021              0.3760
# 4        As          5  2021              0.2651
# ..      ...        ...   ...                 ...
# 280      Pb         47  2021              0.0230
# 281      Pb         48  2021              0.0200
# 282      Pb         49  2021              0.0018
# 283      Pb         50  2021              0.0045
# 284      Pb         51  2021              0.0200
#
# [285 rows x 4 columns]

# %%
data_concatenada = pd.concat([result_12, result_13, result_14, result_15, result_16, result_17, result_18, result_19, result_20, result_21], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 data_concatenada = pd.concat([result_12, result_13, result_14, result_15, result_16, result_17, result_18, result_19, result_20, result_21], ignore_index=True)
#
# NameError: name 'result_14' is not defined

# %%
data_concatenada.to_csv('data_calidad_aire_anual.csv', index=False)

# %%
data_2012 = pd.read_csv("Hospitalizaciones 2012.csv", delimiter="\t", encoding="iso-8859-1")
data_2013 = pd.read_csv("Hospitalizaciones 2013.csv", delimiter="\t", encoding="iso-8859-1")
data_2014 = pd.read_csv("Hospitalizaciones 2014.csv", delimiter="\t", encoding="iso-8859-1")
data_2015 = pd.read_csv("Hospitalizaciones 2015.csv", delimiter="\t", encoding="utf-8")
data_2016 = pd.read_csv("Hospitalizaciones 2016.csv", delimiter="\t", encoding="iso-8859-1")
data_2017 = pd.read_csv("Hospitalizaciones 2017.csv", delimiter="\t", encoding="iso-8859-1")
data_2018 = pd.read_csv("Hospitalizaciones 2018.csv", delimiter="\t", encoding="iso-8859-1")
data_2019 = pd.read_csv("Hospitalizaciones 2019.csv", delimiter="\t", encoding="iso-8859-1")
data_2020 = pd.read_csv("Hospitalizaciones 2020.csv", delimiter="\t", encoding="iso-8859-1")
data_2021 = pd.read_csv("Hospitalizaciones 2021.csv", delimiter="\t", encoding="iso-8859-1")
data_calidad_aire_anual = pd.read_csv("data_calidad_aire_anual.csv", delimiter=",", encoding="iso-8859-1")

# %%
data_2012['Provincia, Comunidad y Ciudad autónoma de residencia'] = data_2012['Provincia, Comunidad y Ciudad autónoma de residencia'].str.lower().replace( {
    "araba/álava": 1,
    "albacete": 2,
    "alicante/alacant": 3,
    "almería": 4,
    "ávila": 5,
    "badajoz": 6,
    "balears, illes": 7,
    "barcelona": 8,
    "burgos": 9,
    "cáceres": 10,
    "cádiz": 11,
    "castellón/castelló": 12,
    "ciudad real": 13,
    "córdoba": 14,
    "coruña, a": 15,
    "cuenca": 16,
    "girona": 17,
    "granada": 18,
    "guadalajara": 19,
    "gipuzkoa": 20,
    "huelva": 21,
    "huesca": 22,
    "jaén": 23,
    "león": 24,
    "lleida": 25,
    "rioja, la": 26,
    "lugo": 27,
    "madrid, comunidad de": 28,
    "málaga": 29,
    "murcia, región de": 30,
    "navarra, comunidad foral de": 31,
    "ourense": 32,
    "asturias, principado de": 33,
    "palencia": 34,
    "palmas, las": 35,
    "pontevedra": 36,
    "salamanca": 37,
    "santa cruz de tenerife": 38,
    "cantabria": 39,
    "segovia": 40,
    "sevilla": 41,
    "soria": 42,
    "tarragona": 43,
    "teruel": 44,
    "toledo": 45,
    "valencia/valència": 46,
    "valladolid": 47,
    "bizkaia": 48,
    "zamora": 49,
    "zaragoza": 50,
    "ceuta": 51,
    "melilla": 52
}
                                                                                                                 )   
data_2012.head(50)
# Out:
#    Provincia, Comunidad y Ciudad autónoma de residencia  \
# 0                                                   4
# 1                                                   4
# 2                                                   4
# 3                                                   4
# 4                                                   4
# 5                                                   4
# 6                                                   4
# 7                                                   4
# 8                                                   4
# 9                                                   4
# 10                                                  4
# 11                                                  4
# 12                                                  4
# 13                                                  4
# 14                                                  4
# 15                                                  4
# ...

# %%
filtro = data_2012['Provincia, Comunidad y Ciudad autónoma de residencia'] == 33
data_2012[filtro]
# Out:
#     Provincia, Comunidad y Ciudad autónoma de residencia  \
# 363                                                 33
# 364                                                 33
# 365                                                 33
# 366                                                 33
# 367                                                 33
# 368                                                 33
# 369                                                 33
# 370                                                 33
# 371                                                 33
# 372                                                 33
# 373                                                 33
# 374                                                 33
# 375                                                 33
# 376                                                 33
# 377                                                 33
# 378                                                 33
# ...

# %%
data_2012.rename(
    columns = {'Provincia, Comunidad y Ciudad autónoma de residencia': 'Provincia_ID'},
    inplace = True
)

# %%
data_2012.to_csv('Hospitalizaciones_2012.csv', index = False)

# %%
data_2013['Provincia, Comunidad y Ciudad autónoma de residencia'] = data_2013['Provincia, Comunidad y Ciudad autónoma de residencia'].str.lower().replace( {
    "araba/álava": 1,
    "albacete": 2,
    "alicante/alacant": 3,
    "almería": 4,
    "ávila": 5,
    "badajoz": 6,
    "balears, illes": 7,
    "barcelona": 8,
    "burgos": 9,
    "cáceres": 10,
    "cádiz": 11,
    "castellón/castelló": 12,
    "ciudad real": 13,
    "córdoba": 14,
    "coruña, a": 15,
    "cuenca": 16,
    "girona": 17,
    "granada": 18,
    "guadalajara": 19,
    "gipuzkoa": 20,
    "huelva": 21,
    "huesca": 22,
    "jaén": 23,
    "león": 24,
    "lleida": 25,
    "rioja, la": 26,
    "lugo": 27,
    "madrid, comunidad de": 28,
    "málaga": 29,
    "murcia, región de": 30,
    "navarra, comunidad foral de": 31,
    "ourense": 32,
    "asturias, principado de": 33,
    "palencia": 34,
    "palmas, las": 35,
    "pontevedra": 36,
    "salamanca": 37,
    "santa cruz de tenerife": 38,
    "cantabria": 39,
    "segovia": 40,
    "sevilla": 41,
    "soria": 42,
    "tarragona": 43,
    "teruel": 44,
    "toledo": 45,
    "valencia/valència": 46,
    "valladolid": 47,
    "bizkaia": 48,
    "zamora": 49,
    "zaragoza": 50,
    "ceuta": 51,
    "melilla": 52
}
                                                                                                                 )   
data_2013.head(50)
# Out:
#    Provincia, Comunidad y Ciudad autónoma de residencia         Sexo  \
# 0                                                   4    Ambos sexos
# 1                                                   4    Ambos sexos
# 2                                                   4    Ambos sexos
# 3                                                   4    Ambos sexos
# 4                                                   4    Ambos sexos
# 5                                                   4    Ambos sexos
# 6                                                   4    Ambos sexos
# 7                                                   4    Ambos sexos
# 8                                                   4    Ambos sexos
# 9                                                   4    Ambos sexos
# 10                                                  4    Ambos sexos
# 11                                                  4        Hombres
# 12                                                  4        Hombres
# ...

# %%
data_2013.rename(
    columns = {'Provincia, Comunidad y Ciudad autónoma de residencia': 'Provincia_ID'},
    inplace = True
)
data_2013
# Out:
#      Provincia_ID         Sexo  \
# 0               4  Ambos sexos
# 1               4  Ambos sexos
# 2               4  Ambos sexos
# 3               4  Ambos sexos
# 4               4  Ambos sexos
# ...           ...          ...
# 1711           52      Mujeres
# 1712           52      Mujeres
# 1713           52      Mujeres
# 1714           52      Mujeres
# 1715           52      Mujeres
#
#                          Diagnóstico principal (CIE9MC)   Total
# 0     162 Neoplasia maligna de tráquea, bronquios y ...   4.027
# 1     415-417 VII.5 ENFERMEDADES DE LA CIRCULACIÓN P...   1.927
# 2     460-519 VIII ENFERMEDADES DEL APARATO RESPIRAT...  49.409
# 3     460-478 VIII.1 INFECCIONES RESPIRATORIAS AGUDA...   7.469
# 4                  466 Bronquitis y bronquiolitis aguda   5.578
# ...                                                 ...     ...
# 1711  Resto (460-478) Otras infecciones respiratoria...     133
# 1712                                   480-486 Neumonía     533
# ...

# %%
data_2013.to_csv('Hospitalizaciones_2013.csv', index = False)

# %%
data_2014['Provincia, Comunidad y Ciudad autónoma de residencia'] = data_2014['Provincia, Comunidad y Ciudad autónoma de residencia'].str.lower().replace( {
    "araba/álava": 1,
    "albacete": 2,
    "alicante/alacant": 3,
    "almería": 4,
    "ávila": 5,
    "badajoz": 6,
    "balears, illes": 7,
    "barcelona": 8,
    "burgos": 9,
    "cáceres": 10,
    "cádiz": 11,
    "castellón/castelló": 12,
    "ciudad real": 13,
    "córdoba": 14,
    "coruña, a": 15,
    "cuenca": 16,
    "girona": 17,
    "granada": 18,
    "guadalajara": 19,
    "gipuzkoa": 20,
    "huelva": 21,
    "huesca": 22,
    "jaén": 23,
    "león": 24,
    "lleida": 25,
    "rioja, la": 26,
    "lugo": 27,
    "madrid, comunidad de": 28,
    "málaga": 29,
    "murcia, región de": 30,
    "navarra, comunidad foral de": 31,
    "ourense": 32,
    "asturias, principado de": 33,
    "palencia": 34,
    "palmas, las": 35,
    "pontevedra": 36,
    "salamanca": 37,
    "santa cruz de tenerife": 38,
    "cantabria": 39,
    "segovia": 40,
    "sevilla": 41,
    "soria": 42,
    "tarragona": 43,
    "teruel": 44,
    "toledo": 45,
    "valencia/valència": 46,
    "valladolid": 47,
    "bizkaia": 48,
    "zamora": 49,
    "zaragoza": 50,
    "ceuta": 51,
    "melilla": 52
}
                                                                                                                 )   
data_2014.head(50)
# Out:
#    Provincia, Comunidad y Ciudad autónoma de residencia  \
# 0                                                   4
# 1                                                   4
# 2                                                   4
# 3                                                   4
# 4                                                   4
# 5                                                   4
# 6                                                   4
# 7                                                   4
# 8                                                   4
# 9                                                   4
# 10                                                  4
# 11                                                  4
# 12                                                  4
# 13                                                  4
# 14                                                  4
# 15                                                  4
# ...

# %%
data_2014.rename(
    columns = {'Provincia, Comunidad y Ciudad autónoma de residencia': 'Provincia_ID'},
    inplace = True
)
data_2014.head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_2014.rename(
#       2     columns = {'Provincia, Comunidad y Ciudad autónoma de residencia': 'Provincia_ID'},
#       3     inplace = True
#       4 )
#       5 data_2014.head(30)
#
# NameError: name 'data_2014' is not defined

# %%
data_2014.to_csv('Hospitalizaciones_2014.csv', index = False)

# %%
data_2015['Provincia, Comunidad y Ciudad autónoma de residencia'] = data_2015['Provincia, Comunidad y Ciudad autónoma de residencia'].str.lower().replace( {
    "araba/álava": 1,
    "albacete": 2,
    "alicante/alacant": 3,
    "almería": 4,
    "ávila": 5,
    "badajoz": 6,
    "balears, illes": 7,
    "barcelona": 8,
    "burgos": 9,
    "cáceres": 10,
    "cádiz": 11,
    "castellón/castelló": 12,
    "ciudad real": 13,
    "córdoba": 14,
    "coruña, a": 15,
    "cuenca": 16,
    "girona": 17,
    "granada": 18,
    "guadalajara": 19,
    "gipuzkoa": 20,
    "huelva": 21,
    "huesca": 22,
    "jaén": 23,
    "león": 24,
    "lleida": 25,
    "rioja, la": 26,
    "lugo": 27,
    "madrid, comunidad de": 28,
    "málaga": 29,
    "murcia, región de": 30,
    "navarra, comunidad foral de": 31,
    "ourense": 32,
    "asturias, principado de": 33,
    "palencia": 34,
    "palmas, las": 35,
    "pontevedra": 36,
    "salamanca": 37,
    "santa cruz de tenerife": 38,
    "cantabria": 39,
    "segovia": 40,
    "sevilla": 41,
    "soria": 42,
    "tarragona": 43,
    "teruel": 44,
    "toledo": 45,
    "valencia/valència": 46,
    "valladolid": 47,
    "bizkaia": 48,
    "zamora": 49,
    "zaragoza": 50,
    "ceuta": 51,
    "melilla": 52
}
                                                                                                                 )   
data_2015.head(50)
# Out:
#            Sexo Diagnóstico principal (CIE9MC)  \
# 0   Ambos sexos               TODAS LAS CAUSAS
# 1   Ambos sexos               TODAS LAS CAUSAS
# 2   Ambos sexos               TODAS LAS CAUSAS
# 3   Ambos sexos               TODAS LAS CAUSAS
# 4   Ambos sexos               TODAS LAS CAUSAS
# 5   Ambos sexos               TODAS LAS CAUSAS
# 6   Ambos sexos               TODAS LAS CAUSAS
# 7   Ambos sexos               TODAS LAS CAUSAS
# 8   Ambos sexos               TODAS LAS CAUSAS
# 9   Ambos sexos               TODAS LAS CAUSAS
# 10  Ambos sexos               TODAS LAS CAUSAS
# 11  Ambos sexos               TODAS LAS CAUSAS
# 12  Ambos sexos               TODAS LAS CAUSAS
# 13  Ambos sexos               TODAS LAS CAUSAS
# 14  Ambos sexos               TODAS LAS CAUSAS
# 15  Ambos sexos               TODAS LAS CAUSAS
# 16  Ambos sexos               TODAS LAS CAUSAS
# 17  Ambos sexos               TODAS LAS CAUSAS
# 18  Ambos sexos               TODAS LAS CAUSAS
# ...

# %%
data_2015.rename(
    columns = {'Provincia, Comunidad y Ciudad autónoma de residencia': 'Provincia_ID'},
    inplace = True
)
data_2015
# Out:
#               Sexo Diagnóstico principal (CIE9MC)    Provincia_ID       Total
# 0      Ambos sexos               TODAS LAS CAUSAS  total nacional  31.624.525
# 1      Ambos sexos               TODAS LAS CAUSAS       andalucía   4.275.428
# 2      Ambos sexos               TODAS LAS CAUSAS               4     355.472
# 3      Ambos sexos               TODAS LAS CAUSAS              11     683.033
# 4      Ambos sexos               TODAS LAS CAUSAS              14     394.417
# ...            ...                            ...             ...         ...
# 38203      Mujeres          ALTAS SIN DIAGNÓSTICO              20       3.866
# 38204      Mujeres          ALTAS SIN DIAGNÓSTICO              26         207
# 38205      Mujeres          ALTAS SIN DIAGNÓSTICO              51           2
# 38206      Mujeres          ALTAS SIN DIAGNÓSTICO              52          44
# 38207      Mujeres          ALTAS SIN DIAGNÓSTICO      extranjero         327
#
# [38208 rows x 4 columns]

# %%
data_2015.to_csv('Hospitalizaciones_2015.csv', index = False)
